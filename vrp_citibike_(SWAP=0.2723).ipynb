# %%
# !pip3 install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.15.6755-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting absl-py>=2.0.0 (from ortools)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.2.2)
# Collecting protobuf<6.34,>=6.33.1 (from ortools)
#   Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from ortools) (4.15.0)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (4.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.17.0)
# Downloading ortools-9.15.6755-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (29.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.8/29.8 MB 56.1 MB/s eta 0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 7.1 MB/s eta 0:00:00
# Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 17.8 MB/s eta 0:00:00
# Installing collected packages: protobuf, absl-py, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.6 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# Successfully installed absl-py-2.4.0 ortools-9.15.6755 protobuf-6.33.6

# %%
import folium

# %%
import pandas as pd

# URL of the distance matrix CSV
url = 'https://raw.githubusercontent.com/sandrotissi/citibike_vrp/226d6d7b050fafc5805837ba8fefe8a65d2c6996/full_distance_matrix_google.csv'

# Read the CSV into a pandas DataFrame
distance_df = pd.read_csv(url, index_col=0)

# Scale distances by 1000 and convert to integers to avoid OR-Tools truncating small floating-point values to 0
new_distance_matrix = [[int(val * 1000) for val in row] for row in distance_df.values.tolist()]

print(f"Loaded a distance matrix of shape: {len(new_distance_matrix)}x{len(new_distance_matrix[0])}")
# Out:
# Loaded a distance matrix of shape: 111x111

# %%
demand_url = 'https://raw.githubusercontent.com/sandrotissi/citibike_vrp/5835068e495eca41dc51875170e7e511b84b8db6/all_archetypes_demand_with_coordinates_swap0.2723.csv'
demand_df = pd.read_csv(demand_url)

# %% [markdown]
# ### Optimization for `demand_001` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_001 = [0] + demand_df['demand_001'].tolist()

def create_data_model_001():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_001]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_001(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0: # Check if the vehicle was actually used
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_001():
    """Solve the CVRP problem."""
    data = create_data_model_001()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_001(data, manager, routing, solution)


if __name__ == '__main__':
    main_001()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  18 Load(8) ->  64 Load(12) ->  43 Load(18) ->  89 Load(19) ->  100 Load(20) ->  99 Load(21) ->  106 Load(22) ->  105 Load(23) ->  104 Load(24) ->  101 Load(25) ->  103 Load(26) ->  109 Load(27) ->  102 Load(28) ->  97 Load(29) ->  98 Load(31) ->  94 Load(33) ->  52 Load(35) ->  110 Load(36) ->  92 Load(38) ->  91 Load(40) ->  65 Load(44) ->  73 Load(49) ->  54 Load(53) ->  71 Load(58) ->  78 Load(65) ->  42 Load(72) -> 0
# Distance of the route: 60535m
# Load of the route: 72
#
# Route for vehicle 8:
#  0 Load(0) ->  41 Load(3) ->  59 Load(7) ->  72 Load(11) ->  55 Load(20) ->  83 Load(34) ->  80 Load(43) -> 0
# Distance of the route: 41941m
# Load of the route: 43
#
# Route for vehicle 9:
#  0 Load(0) ->  85 Load(21) ->  53 Load(27) ->  87 Load(30) ->  66 Load(34) ->  70 Load(38) ->  90 Load(41) ->  93 Load(43) ->  81 Load(44) ->  58 Load(46) ->  95 Load(47) ->  107 Load(48) ->  82 Load(50) ->  108 Load(51) ->  96 Load(52) ->  88 Load(57) ->  35 Load(64) ->  36 Load(71) -> 0
# Distance of the route: 49576m
# Load of the route: 71
#
# Route for vehicle 10:
#  0 Load(0) ->  1 Load(15) ->  2 Load(15) ->  3 Load(24) ->  32 Load(31) ->  28 Load(41) ->  10 Load(47) ->  13 Load(55) ->  12 Load(63) ->  16 Load(68) -> 0
# Distance of the route: 41037m
# Load of the route: 68
#
# Route for vehicle 11:
#  0 Load(0) ->  49 Load(6) ->  44 Load(13) ->  46 Load(19) ->  67 Load(22) ->  56 Load(28) ->  57 Load(32) ->  8 Load(37) ->  7 Load(47) ->  6 Load(55) ->  21 Load(66) ->  29 Load(71) -> 0
# Distance of the route: 44806m
# Load of the route: 71
#
# Route for vehicle 12:
#  0 Load(0) ->  15 Load(9) ->  17 Load(15) ->  19 Load(21) ->  4 Load(29) ->  33 Load(38) ->  30 Load(50) ->  5 Load(71) -> 0
# Distance of the route: 38040m
# Load of the route: 71
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(6) ->  60 Load(14) ->  75 Load(20) ->  79 Load(25) ->  86 Load(34) ->  77 Load(40) ->  61 Load(46) ->  51 Load(50) ->  34 Load(54) ->  40 Load(61) ->  39 Load(68) ->  74 Load(72) -> 0
# Distance of the route: 42434m
# Load of the route: 72
#
# Route for vehicle 14:
#  0 Load(0) ->  27 Load(8) ->  26 Load(16) ->  11 Load(24) ->  20 Load(36) ->  23 Load(44) ->  31 Load(49) ->  24 Load(50) ->  25 Load(55) ->  22 Load(56) ->  9 Load(64) ->  14 Load(71) -> 0
# Distance of the route: 42345m
# Load of the route: 71
#
# Route for vehicle 15:
#  0 Load(0) ->  38 Load(11) ->  68 Load(17) ->  63 Load(22) ->  45 Load(29) ->  76 Load(33) ->  84 Load(38) ->  50 Load(43) ->  48 Load(50) ->  69 Load(57) ->  62 Load(62) ->  47 Load(66) -> 0
# Distance of the route: 39913m
# Load of the route: 66
#
# Total distance driven by all vehicles: 400627m
# Number of vans used: 9

# %% [markdown]
# ### Optimization for `demand_011` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_011 = [0] + demand_df['demand_011'].tolist()

def create_data_model_011():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_011]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_011(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_011():
    """Solve the CVRP problem."""
    data = create_data_model_011()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_011(data, manager, routing, solution)


if __name__ == '__main__':
    main_011()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  14 Load(10) ->  18 Load(21) ->  16 Load(29) ->  12 Load(40) ->  22 Load(40) ->  25 Load(47) ->  28 Load(61) ->  27 Load(72) -> 0
# Distance of the route: 40987m
# Load of the route: 72
#
# Route for vehicle 5:
#  0 Load(0) ->  13 Load(12) ->  31 Load(20) ->  24 Load(26) ->  8 Load(35) ->  7 Load(51) ->  6 Load(65) -> 0
# Distance of the route: 41615m
# Load of the route: 65
#
# Route for vehicle 6:
#  0 Load(0) ->  29 Load(7) ->  26 Load(17) ->  11 Load(28) ->  20 Load(43) ->  10 Load(50) ->  9 Load(59) ->  19 Load(67) -> 0
# Distance of the route: 39564m
# Load of the route: 67
#
# Route for vehicle 7:
#  0 Load(0) ->  68 Load(8) ->  76 Load(13) ->  53 Load(24) ->  87 Load(25) ->  88 Load(27) ->  66 Load(34) ->  70 Load(40) ->  90 Load(41) ->  89 Load(42) ->  93 Load(43) ->  107 Load(43) ->  97 Load(43) ->  101 Load(43) ->  106 Load(43) ->  105 Load(43) ->  104 Load(43) ->  103 Load(43) ->  109 Load(43) ->  102 Load(43) ->  98 Load(44) ->  110 Load(44) ->  54 Load(51) ->  73 Load(57) ->  71 Load(63) ->  72 Load(68) ->  41 Load(72) -> 0
# Distance of the route: 57627m
# Load of the route: 72
#
# Route for vehicle 8:
#  0 Load(0) ->  59 Load(6) ->  52 Load(10) ->  94 Load(11) ->  95 Load(12) ->  82 Load(15) ->  108 Load(15) ->  96 Load(16) ->  100 Load(16) ->  99 Load(16) ->  81 Load(18) ->  58 Load(21) ->  92 Load(22) ->  91 Load(23) ->  65 Load(29) ->  43 Load(39) ->  55 Load(52) ->  78 Load(62) ->  42 Load(70) -> 0
# Distance of the route: 51999m
# Load of the route: 70
#
# Route for vehicle 9:
#  0 Load(0) ->  30 Load(16) ->  32 Load(26) ->  3 Load(39) ->  1 Load(60) -> 0
# Distance of the route: 37479m
# Load of the route: 60
#
# Route for vehicle 10:
#  0 Load(0) ->  62 Load(6) ->  64 Load(11) ->  84 Load(19) ->  39 Load(31) ->  40 Load(41) ->  34 Load(48) ->  60 Load(60) ->  37 Load(72) -> 0
# Distance of the route: 42386m
# Load of the route: 72
#
# Route for vehicle 11:
#  0 Load(0) ->  15 Load(12) ->  17 Load(20) ->  56 Load(28) ->  57 Load(34) ->  23 Load(43) ->  21 Load(58) ->  4 Load(72) -> 0
# Distance of the route: 42095m
# Load of the route: 72
#
# Route for vehicle 12:
#  0 Load(0) ->  38 Load(15) ->  45 Load(25) ->  63 Load(31) ->  33 Load(40) ->  5 Load(59) ->  2 Load(71) -> 0
# Distance of the route: 40019m
# Load of the route: 71
#
# Route for vehicle 13:
#  0 Load(0) ->  75 Load(9) ->  36 Load(19) ->  79 Load(28) ->  86 Load(41) ->  51 Load(47) ->  61 Load(55) ->  77 Load(63) ->  74 Load(68) -> 0
# Distance of the route: 40010m
# Load of the route: 68
#
# Route for vehicle 14:
#  0 Load(0) ->  49 Load(7) ->  44 Load(16) ->  46 Load(25) ->  67 Load(30) ->  83 Load(47) ->  80 Load(64) -> 0
# Distance of the route: 41417m
# Load of the route: 64
#
# Route for vehicle 15:
#  0 Load(0) ->  85 Load(27) ->  35 Load(36) ->  50 Load(43) ->  48 Load(54) ->  69 Load(64) ->  47 Load(70) -> 0
# Distance of the route: 37820m
# Load of the route: 70
#
# Total distance driven by all vehicles: 513018m
# Number of vans used: 12

# %% [markdown]
# ### Optimization for `demand_101` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_101 = [0] + demand_df['demand_101'].tolist()

def create_data_model_101():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_101]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_101(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_101():
    """Solve the CVRP problem."""
    data = create_data_model_101()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_101(data, manager, routing, solution)


if __name__ == '__main__':
    main_101()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  4 Load(8) ->  33 Load(17) ->  30 Load(28) ->  5 Load(45) -> 0
# Distance of the route: 36720m
# Load of the route: 45
#
# Route for vehicle 9:
#  0 Load(0) ->  38 Load(9) ->  68 Load(13) ->  87 Load(16) ->  53 Load(21) ->  88 Load(26) ->  66 Load(30) ->  70 Load(34) ->  89 Load(35) ->  93 Load(37) ->  81 Load(38) ->  96 Load(39) ->  100 Load(40) ->  99 Load(41) ->  106 Load(42) ->  105 Load(43) ->  104 Load(44) ->  103 Load(45) ->  109 Load(46) ->  102 Load(47) ->  97 Load(48) ->  98 Load(50) ->  94 Load(52) ->  52 Load(54) ->  110 Load(55) ->  54 Load(59) ->  71 Load(62) ->  78 Load(66) ->  42 Load(72) -> 0
# Distance of the route: 56676m
# Load of the route: 72
#
# Route for vehicle 10:
#  0 Load(0) ->  49 Load(5) ->  44 Load(10) ->  41 Load(13) ->  59 Load(16) ->  72 Load(19) ->  55 Load(26) ->  43 Load(33) ->  73 Load(37) ->  65 Load(40) ->  90 Load(42) ->  92 Load(44) ->  95 Load(45) ->  107 Load(46) ->  82 Load(48) ->  101 Load(49) ->  108 Load(50) ->  58 Load(52) ->  91 Load(54) ->  83 Load(64) ->  80 Load(72) -> 0
# Distance of the route: 52555m
# Load of the route: 72
#
# Route for vehicle 11:
#  0 Load(0) ->  46 Load(4) ->  67 Load(7) ->  56 Load(12) ->  57 Load(16) ->  23 Load(24) ->  21 Load(34) ->  6 Load(42) ->  7 Load(51) ->  8 Load(56) ->  24 Load(57) ->  25 Load(62) ->  22 Load(63) ->  18 Load(71) -> 0
# Distance of the route: 45860m
# Load of the route: 71
#
# Route for vehicle 12:
#  0 Load(0) ->  14 Load(6) ->  16 Load(10) ->  12 Load(16) ->  13 Load(22) ->  31 Load(27) ->  28 Load(37) ->  27 Load(43) ->  32 Load(49) ->  3 Load(58) ->  2 Load(58) ->  1 Load(72) -> 0
# Distance of the route: 41635m
# Load of the route: 72
#
# Route for vehicle 13:
#  0 Load(0) ->  47 Load(4) ->  62 Load(9) ->  63 Load(13) ->  45 Load(18) ->  64 Load(22) ->  76 Load(25) ->  84 Load(29) ->  50 Load(34) ->  48 Load(41) ->  69 Load(47) ->  75 Load(52) ->  60 Load(58) ->  37 Load(64) -> 0
# Distance of the route: 42069m
# Load of the route: 64
#
# Route for vehicle 14:
#  0 Load(0) ->  19 Load(5) ->  9 Load(12) ->  10 Load(17) ->  20 Load(26) ->  11 Load(34) ->  26 Load(42) ->  29 Load(48) ->  17 Load(54) ->  15 Load(61) -> 0
# Distance of the route: 40253m
# Load of the route: 61
#
# Route for vehicle 15:
#  0 Load(0) ->  36 Load(6) ->  79 Load(10) ->  86 Load(18) ->  77 Load(23) ->  61 Load(28) ->  51 Load(31) ->  34 Load(34) ->  40 Load(41) ->  85 Load(56) ->  35 Load(61) ->  39 Load(67) ->  74 Load(70) -> 0
# Distance of the route: 41639m
# Load of the route: 70
#
# Total distance driven by all vehicles: 357407m
# Number of vans used: 8

# %% [markdown]
# ### Optimization for `demand_111` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_111 = [0] + demand_df['demand_111'].tolist()

def create_data_model_111():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_111]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_111(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_111():
    """Solve the CVRP problem."""
    data = create_data_model_111()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_111(data, manager, routing, solution)


if __name__ == '__main__':
    main_111()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  59 Load(4) ->  71 Load(10) ->  72 Load(14) ->  55 Load(23) ->  43 Load(33) ->  73 Load(39) ->  65 Load(44) ->  54 Load(52) ->  110 Load(52) ->  52 Load(56) ->  94 Load(57) ->  95 Load(58) ->  108 Load(58) ->  81 Load(60) ->  58 Load(63) ->  90 Load(64) ->  68 Load(70) -> 0
# Distance of the route: 51226m
# Load of the route: 70
#
# Route for vehicle 6:
#  0 Load(0) ->  44 Load(8) ->  18 Load(17) ->  14 Load(26) ->  16 Load(33) ->  9 Load(41) ->  11 Load(51) ->  26 Load(61) ->  19 Load(68) -> 0
# Distance of the route: 41534m
# Load of the route: 68
#
# Route for vehicle 7:
#  0 Load(0) ->  32 Load(10) ->  27 Load(18) ->  28 Load(30) ->  6 Load(44) ->  7 Load(60) ->  8 Load(70) -> 0
# Distance of the route: 41530m
# Load of the route: 70
#
# Route for vehicle 8:
#  0 Load(0) ->  35 Load(8) ->  53 Load(23) ->  87 Load(25) ->  88 Load(27) ->  66 Load(33) ->  70 Load(39) ->  89 Load(40) ->  93 Load(41) ->  96 Load(42) ->  100 Load(42) ->  99 Load(42) ->  106 Load(42) ->  105 Load(42) ->  104 Load(42) ->  103 Load(42) ->  109 Load(42) ->  102 Load(42) ->  98 Load(43) ->  97 Load(43) ->  101 Load(43) ->  82 Load(46) ->  107 Load(46) ->  92 Load(47) ->  91 Load(48) ->  83 Load(62) ->  78 Load(68) -> 0
# Distance of the route: 56503m
# Load of the route: 68
#
# Route for vehicle 9:
#  0 Load(0) ->  1 Load(19) ->  3 Load(34) ->  2 Load(42) ->  5 Load(57) ->  30 Load(71) -> 0
# Distance of the route: 36855m
# Load of the route: 71
#
# Route for vehicle 10:
#  0 Load(0) ->  85 Load(25) ->  39 Load(37) ->  74 Load(41) ->  51 Load(46) ->  34 Load(52) ->  40 Load(62) ->  36 Load(72) -> 0
# Distance of the route: 39992m
# Load of the route: 72
#
# Route for vehicle 11:
#  0 Load(0) ->  47 Load(5) ->  62 Load(12) ->  69 Load(21) ->  48 Load(33) ->  50 Load(40) ->  84 Load(48) ->  76 Load(53) ->  64 Load(58) ->  45 Load(67) ->  63 Load(71) -> 0
# Distance of the route: 39732m
# Load of the route: 71
#
# Route for vehicle 12:
#  0 Load(0) ->  38 Load(15) ->  33 Load(26) ->  4 Load(38) ->  29 Load(46) ->  17 Load(54) ->  15 Load(64) -> 0
# Distance of the route: 39172m
# Load of the route: 64
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(13) ->  60 Load(24) ->  79 Load(32) ->  86 Load(47) ->  61 Load(55) ->  77 Load(62) ->  75 Load(71) -> 0
# Distance of the route: 40727m
# Load of the route: 71
#
# Route for vehicle 14:
#  0 Load(0) ->  49 Load(7) ->  56 Load(16) ->  23 Load(24) ->  20 Load(36) ->  13 Load(46) ->  12 Load(54) ->  80 Load(71) -> 0
# Distance of the route: 42158m
# Load of the route: 71
#
# Route for vehicle 15:
#  0 Load(0) ->  42 Load(8) ->  41 Load(13) ->  67 Load(18) ->  46 Load(26) ->  57 Load(31) ->  21 Load(46) ->  31 Load(54) ->  24 Load(60) ->  25 Load(67) ->  22 Load(67) ->  10 Load(72) -> 0
# Distance of the route: 46942m
# Load of the route: 72
#
# Total distance driven by all vehicles: 476371m
# Number of vans used: 11

# %% [markdown]
# ### Optimization for `demand_100` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_100 = [0] + demand_df['demand_100'].tolist()

def create_data_model_100():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_100]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_100(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_100():
    """Solve the CVRP problem."""
    data = create_data_model_100()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_100(data, manager, routing, solution)


if __name__ == '__main__':
    main_100()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  80 Load(9) ->  25 Load(13) ->  22 Load(14) ->  13 Load(20) ->  12 Load(26) ->  26 Load(34) ->  27 Load(39) ->  32 Load(46) ->  3 Load(54) ->  2 Load(54) ->  1 Load(70) -> 0
# Distance of the route: 41373m
# Load of the route: 70
#
# Route for vehicle 9:
#  0 Load(0) ->  47 Load(4) ->  62 Load(9) ->  69 Load(16) ->  48 Load(23) ->  64 Load(27) ->  43 Load(34) ->  55 Load(42) ->  71 Load(46) ->  83 Load(58) ->  41 Load(62) ->  49 Load(67) -> 0
# Distance of the route: 42887m
# Load of the route: 67
#
# Route for vehicle 10:
#  0 Load(0) ->  38 Load(10) ->  68 Load(15) ->  73 Load(19) ->  65 Load(22) ->  91 Load(24) ->  92 Load(26) ->  58 Load(29) ->  81 Load(30) ->  96 Load(31) ->  108 Load(32) ->  82 Load(33) ->  101 Load(34) ->  99 Load(35) ->  100 Load(36) ->  106 Load(37) ->  105 Load(38) ->  104 Load(39) ->  103 Load(39) ->  109 Load(40) ->  102 Load(41) ->  98 Load(43) ->  97 Load(43) ->  107 Load(44) ->  95 Load(45) ->  94 Load(47) ->  52 Load(49) ->  110 Load(50) ->  54 Load(55) ->  72 Load(57) ->  59 Load(60) ->  78 Load(64) ->  42 Load(69) -> 0
# Distance of the route: 60583m
# Load of the route: 69
#
# Route for vehicle 11:
#  0 Load(0) ->  44 Load(6) ->  46 Load(11) ->  67 Load(14) ->  56 Load(18) ->  57 Load(22) ->  8 Load(27) ->  7 Load(36) ->  6 Load(43) ->  21 Load(54) ->  28 Load(63) ->  33 Load(71) -> 0
# Distance of the route: 45315m
# Load of the route: 71
#
# Route for vehicle 12:
#  0 Load(0) ->  15 Load(11) ->  17 Load(18) ->  29 Load(23) ->  4 Load(30) ->  30 Load(40) ->  5 Load(55) -> 0
# Distance of the route: 37745m
# Load of the route: 55
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(6) ->  60 Load(12) ->  75 Load(16) ->  79 Load(20) ->  86 Load(28) ->  34 Load(31) ->  51 Load(34) ->  61 Load(39) ->  77 Load(43) ->  39 Load(48) ->  74 Load(51) ->  40 Load(58) ->  36 Load(64) -> 0
# Distance of the route: 42426m
# Load of the route: 64
#
# Route for vehicle 14:
#  0 Load(0) ->  14 Load(7) ->  18 Load(12) ->  16 Load(15) ->  10 Load(19) ->  20 Load(28) ->  23 Load(36) ->  24 Load(37) ->  31 Load(42) ->  11 Load(51) ->  9 Load(57) ->  19 Load(61) -> 0
# Distance of the route: 42093m
# Load of the route: 61
#
# Route for vehicle 15:
#  0 Load(0) ->  63 Load(4) ->  45 Load(12) ->  76 Load(16) ->  53 Load(22) ->  87 Load(25) ->  88 Load(30) ->  70 Load(33) ->  90 Load(36) ->  93 Load(39) ->  89 Load(40) ->  66 Load(45) ->  84 Load(49) ->  50 Load(52) ->  35 Load(57) ->  85 Load(72) -> 0
# Distance of the route: 45747m
# Load of the route: 72
#
# Total distance driven by all vehicles: 358169m
# Number of vans used: 8

# %% [markdown]
# ### Optimization for `demand_110` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_110 = [0] + demand_df['demand_110'].tolist()

def create_data_model_110():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_110]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_110(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_110():
    """Solve the CVRP problem."""
    data = create_data_model_110()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_110(data, manager, routing, solution)


if __name__ == '__main__':
    main_110()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  38 Load(14) ->  45 Load(21) ->  62 Load(27) ->  85 Load(48) ->  35 Load(54) ->  40 Load(63) ->  36 Load(72) -> 0
# Distance of the route: 39196m
# Load of the route: 72
#
# Route for vehicle 7:
#  0 Load(0) ->  68 Load(7) ->  76 Load(11) ->  73 Load(17) ->  65 Load(21) ->  54 Load(28) ->  110 Load(28) ->  52 Load(31) ->  94 Load(32) ->  95 Load(33) ->  107 Load(33) ->  108 Load(33) ->  82 Load(36) ->  101 Load(36) ->  97 Load(36) ->  98 Load(36) ->  102 Load(36) ->  109 Load(36) ->  103 Load(36) ->  104 Load(36) ->  105 Load(36) ->  106 Load(36) ->  99 Load(36) ->  100 Load(36) ->  96 Load(36) ->  81 Load(38) ->  58 Load(41) ->  92 Load(42) ->  91 Load(43) ->  90 Load(44) ->  93 Load(45) ->  89 Load(45) ->  64 Load(50) ->  63 Load(54) ->  80 Load(69) -> 0
# Distance of the route: 62681m
# Load of the route: 69
#
# Route for vehicle 8:
#  0 Load(0) ->  42 Load(7) ->  83 Load(21) ->  71 Load(27) ->  87 Load(28) ->  53 Load(40) ->  39 Load(51) ->  74 Load(55) ->  69 Load(63) ->  47 Load(67) -> 0
# Distance of the route: 43471m
# Load of the route: 67
#
# Route for vehicle 9:
#  0 Load(0) ->  19 Load(7) ->  10 Load(13) ->  20 Load(24) ->  23 Load(31) ->  21 Load(43) ->  28 Load(54) ->  13 Load(64) ->  12 Load(72) -> 0
# Distance of the route: 41769m
# Load of the route: 72
#
# Route for vehicle 10:
#  0 Load(0) ->  48 Load(10) ->  50 Load(17) ->  84 Load(24) ->  66 Load(30) ->  88 Load(31) ->  70 Load(36) ->  43 Load(45) ->  55 Load(53) ->  72 Load(56) ->  59 Load(60) ->  78 Load(66) ->  41 Load(69) -> 0
# Distance of the route: 44648m
# Load of the route: 69
#
# Route for vehicle 11:
#  0 Load(0) ->  49 Load(6) ->  44 Load(11) ->  46 Load(17) ->  67 Load(22) ->  56 Load(29) ->  57 Load(34) ->  8 Load(42) ->  7 Load(56) ->  6 Load(67) -> 0
# Distance of the route: 44505m
# Load of the route: 67
#
# Route for vehicle 12:
#  0 Load(0) ->  1 Load(18) ->  2 Load(32) ->  5 Load(42) ->  30 Load(53) ->  33 Load(60) ->  4 Load(72) -> 0
# Distance of the route: 36719m
# Load of the route: 72
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(11) ->  60 Load(21) ->  34 Load(27) ->  51 Load(31) ->  61 Load(38) ->  77 Load(44) ->  86 Load(57) ->  79 Load(64) ->  75 Load(71) -> 0
# Distance of the route: 41053m
# Load of the route: 71
#
# Route for vehicle 14:
#  0 Load(0) ->  29 Load(6) ->  3 Load(14) ->  32 Load(23) ->  27 Load(30) ->  26 Load(39) ->  17 Load(46) ->  15 Load(56) -> 0
# Distance of the route: 39389m
# Load of the route: 56
#
# Route for vehicle 15:
#  0 Load(0) ->  18 Load(10) ->  22 Load(10) ->  25 Load(15) ->  24 Load(22) ->  31 Load(28) ->  11 Load(37) ->  9 Load(44) ->  16 Load(52) ->  14 Load(59) -> 0
# Distance of the route: 41063m
# Load of the route: 59
#
# Total distance driven by all vehicles: 434494m
# Number of vans used: 10

# %% [markdown]
# ### Optimization for `demand_010` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_010 = [0] + demand_df['demand_010'].tolist()

def create_data_model_010():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_010]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_010(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_010():
    """Solve the CVRP problem."""
    data = create_data_model_010()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_010(data, manager, routing, solution)


if __name__ == '__main__':
    main_010()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  12 Load(11) ->  13 Load(22) ->  20 Load(35) ->  11 Load(45) ->  26 Load(54) ->  29 Load(60) ->  19 Load(67) -> 0
# Distance of the route: 39600m
# Load of the route: 67
#
# Route for vehicle 6:
#  0 Load(0) ->  38 Load(14) ->  68 Load(21) ->  83 Load(37) ->  59 Load(42) ->  41 Load(46) ->  46 Load(54) ->  44 Load(63) ->  49 Load(70) -> 0
# Distance of the route: 42204m
# Load of the route: 70
#
# Route for vehicle 7:
#  0 Load(0) ->  47 Load(5) ->  50 Load(11) ->  53 Load(21) ->  87 Load(22) ->  88 Load(23) ->  70 Load(29) ->  66 Load(36) ->  76 Load(41) ->  64 Load(46) ->  56 Load(54) ->  57 Load(59) ->  18 Load(69) -> 0
# Distance of the route: 46743m
# Load of the route: 69
#
# Route for vehicle 8:
#  0 Load(0) ->  35 Load(7) ->  85 Load(31) ->  39 Load(41) ->  74 Load(45) ->  40 Load(53) ->  36 Load(61) -> 0
# Distance of the route: 38661m
# Load of the route: 61
#
# Route for vehicle 9:
#  0 Load(0) ->  3 Load(10) ->  32 Load(18) ->  27 Load(28) ->  6 Load(39) ->  7 Load(54) ->  8 Load(62) ->  10 Load(68) -> 0
# Distance of the route: 42119m
# Load of the route: 68
#
# Route for vehicle 10:
#  0 Load(0) ->  45 Load(8) ->  43 Load(17) ->  90 Load(18) ->  89 Load(19) ->  93 Load(20) ->  108 Load(20) ->  82 Load(23) ->  107 Load(23) ->  95 Load(24) ->  94 Load(25) ->  52 Load(28) ->  110 Load(28) ->  54 Load(35) ->  71 Load(41) ->  72 Load(45) ->  55 Load(56) ->  78 Load(64) ->  42 Load(70) -> 0
# Distance of the route: 49563m
# Load of the route: 70
#
# Route for vehicle 11:
#  0 Load(0) ->  1 Load(20) ->  2 Load(31) ->  5 Load(47) ->  33 Load(56) ->  4 Load(68) -> 0
# Distance of the route: 36607m
# Load of the route: 68
#
# Route for vehicle 12:
#  0 Load(0) ->  22 Load(0) ->  25 Load(6) ->  24 Load(14) ->  31 Load(20) ->  23 Load(28) ->  21 Load(42) ->  28 Load(55) ->  30 Load(69) -> 0
# Distance of the route: 41887m
# Load of the route: 69
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(9) ->  60 Load(19) ->  34 Load(26) ->  51 Load(31) ->  61 Load(39) ->  77 Load(46) ->  86 Load(57) ->  79 Load(64) ->  75 Load(71) -> 0
# Distance of the route: 41053m
# Load of the route: 71
#
# Route for vehicle 14:
#  0 Load(0) ->  80 Load(15) ->  16 Load(23) ->  9 Load(32) ->  17 Load(39) ->  15 Load(50) -> 0
# Distance of the route: 38278m
# Load of the route: 50
#
# Route for vehicle 15:
#  0 Load(0) ->  14 Load(10) ->  67 Load(15) ->  73 Load(21) ->  65 Load(26) ->  91 Load(27) ->  92 Load(28) ->  58 Load(31) ->  81 Load(33) ->  96 Load(34) ->  100 Load(34) ->  99 Load(34) ->  101 Load(34) ->  97 Load(34) ->  98 Load(35) ->  102 Load(35) ->  109 Load(35) ->  103 Load(35) ->  104 Load(35) ->  105 Load(35) ->  106 Load(35) ->  84 Load(41) ->  48 Load(50) ->  69 Load(58) ->  62 Load(64) ->  63 Load(70) -> 0
# Distance of the route: 58782m
# Load of the route: 70
#
# Total distance driven by all vehicles: 475497m
# Number of vans used: 11

# %% [markdown]
# ### Optimization for `demand_000` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_000 = [0] + demand_df['demand_000'].tolist()

def create_data_model_000():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_000]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_000(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_000():
    """Solve the CVRP problem."""
    data = create_data_model_000()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_000(data, manager, routing, solution)


if __name__ == '__main__':
    main_000()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  68 Load(5) ->  63 Load(9) ->  53 Load(14) ->  87 Load(18) ->  88 Load(23) ->  70 Load(26) ->  90 Load(28) ->  89 Load(29) ->  93 Load(31) ->  96 Load(32) ->  81 Load(33) ->  58 Load(35) ->  108 Load(36) ->  82 Load(38) ->  101 Load(39) ->  100 Load(40) ->  99 Load(41) ->  106 Load(42) ->  105 Load(43) ->  104 Load(44) ->  103 Load(45) ->  109 Load(46) ->  102 Load(47) ->  98 Load(49) ->  97 Load(50) ->  107 Load(51) ->  95 Load(52) ->  92 Load(54) ->  94 Load(56) ->  52 Load(58) ->  110 Load(59) ->  54 Load(63) ->  78 Load(70) -> 0
# Distance of the route: 61417m
# Load of the route: 70
#
# Route for vehicle 9:
#  0 Load(0) ->  15 Load(8) ->  17 Load(14) ->  26 Load(22) ->  9 Load(30) ->  10 Load(35) ->  13 Load(43) ->  12 Load(50) ->  16 Load(54) ->  18 Load(61) ->  14 Load(67) -> 0
# Distance of the route: 40638m
# Load of the route: 67
#
# Route for vehicle 10:
#  0 Load(0) ->  42 Load(6) ->  41 Load(9) ->  83 Load(22) ->  59 Load(25) ->  72 Load(28) ->  71 Load(33) ->  55 Load(41) ->  43 Load(47) ->  73 Load(52) ->  65 Load(55) ->  91 Load(58) ->  66 Load(62) ->  84 Load(66) ->  35 Load(72) -> 0
# Distance of the route: 47246m
# Load of the route: 72
#
# Route for vehicle 11:
#  0 Load(0) ->  19 Load(5) ->  11 Load(12) ->  20 Load(23) ->  23 Load(30) ->  21 Load(40) ->  6 Load(49) ->  7 Load(59) ->  8 Load(64) ->  24 Load(65) ->  25 Load(68) ->  22 Load(69) -> 0
# Distance of the route: 41942m
# Load of the route: 69
#
# Route for vehicle 12:
#  0 Load(0) ->  4 Load(8) ->  33 Load(17) ->  5 Load(36) ->  30 Load(47) ->  2 Load(47) ->  3 Load(56) ->  1 Load(70) -> 0
# Distance of the route: 37141m
# Load of the route: 70
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(5) ->  60 Load(13) ->  75 Load(18) ->  79 Load(23) ->  86 Load(32) ->  34 Load(37) ->  51 Load(40) ->  61 Load(45) ->  77 Load(50) ->  39 Load(56) ->  74 Load(60) ->  40 Load(66) ->  36 Load(72) -> 0
# Distance of the route: 42426m
# Load of the route: 72
#
# Route for vehicle 14:
#  0 Load(0) ->  49 Load(5) ->  44 Load(12) ->  46 Load(17) ->  67 Load(20) ->  56 Load(25) ->  57 Load(29) ->  31 Load(35) ->  28 Load(45) ->  27 Load(53) ->  32 Load(59) ->  29 Load(64) ->  80 Load(72) -> 0
# Distance of the route: 46575m
# Load of the route: 72
#
# Route for vehicle 15:
#  0 Load(0) ->  38 Load(10) ->  47 Load(14) ->  48 Load(21) ->  69 Load(28) ->  62 Load(32) ->  45 Load(38) ->  64 Load(41) ->  76 Load(45) ->  50 Load(50) ->  85 Load(67) -> 0
# Distance of the route: 39776m
# Load of the route: 67
#
# Total distance driven by all vehicles: 357161m
# Number of vans used: 8

# %%
import folium

def get_routes_and_coordinates(data, manager, routing, solution, location_coords, new_waypoints):
    """Extracts routes and corresponding coordinates."""
    all_routes_coords = []

    for vehicle_id in range(data['num_vehicles']):
        route_coords = []
        index = routing.Start(vehicle_id) # This `index` is the depot's internal OR-Tools index

        # 1. Add the depot as the starting point
        depot_node_idx = manager.IndexToNode(index)
        depot_coords = location_coords[depot_node_idx]
        route_coords.append(depot_coords)

        # 2. Add the new waypoints immediately after the depot for visualization (outbound)
        route_coords.extend(new_waypoints)

        # 3. Traverse the OR-Tools solution to get all actual stops
        actual_stops_coords = []
        current_route_index = index
        current_route_index = solution.Value(routing.NextVar(current_route_index))

        while not routing.IsEnd(current_route_index):
            node_index = manager.IndexToNode(current_route_index)
            actual_stops_coords.append(location_coords[node_index])
            current_route_index = solution.Value(routing.NextVar(current_route_index))

        route_coords.extend(actual_stops_coords)

        # 4. Add the new waypoints before returning to the depot (inbound)
        # It's more realistic to traverse them in reverse order
        route_coords.extend(list(reversed(new_waypoints)))

        # 5. Add the final depot coordinate
        # The OR-Tools solution implicitly ends at the depot, so we'll just add the depot coords.
        route_coords.append(depot_coords)

        all_routes_coords.append(route_coords)

    return all_routes_coords

# Re-run main to get the solution object for demand_000
data = create_data_model_000()
manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                       data['num_vehicles'], data['depot'])
routing = pywrapcp.RoutingModel(manager)

# Create and register a transit callback (same as in main)
def distance_callback(from_index, to_index):
    return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]
transit_callback_index = routing.RegisterTransitCallback(distance_callback)
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# Add Capacity constraint (same as in main)
def demand_callback(from_index):
    return data['demands'][manager.IndexToNode(from_index)]
demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
routing.AddDimensionWithVehicleCapacity(
    demand_callback_index,
    0,  # null capacity slack
    data['vehicle_capacities'],  # vehicle maximum capacities
    True,  # start cumul to zero
    'Capacity')

search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

solution = routing.SolveWithParameters(search_parameters)

if solution:
    location_coords = {}
    # Get coordinates for all stations from demand_df (node_index 1 corresponds to first row of demand_df)
    for idx, row in demand_df.iterrows():
        # demand_df has 110 rows, corresponding to nodes 1-110
        # idx in demand_df corresponds to node_index = idx + 1
        location_coords[idx + 1] = (row['latitude'], row['longitude'])

    # Add the depot (index 0) with the user-provided coordinates
    depot_lat = 40.646567
    depot_lon = -74.016319
    location_coords[0] = (depot_lat, depot_lon)

    # Define the new waypoints for visualization only (moved outside the function)
    new_waypoints = [
        (40.666659, -73.995811),
        (40.690608, -74.011917),
        (40.704701, -74.016795),
        (40.726184, -74.011653),
        (40.728652, -74.031560)
    ]

    all_routes_coords = get_routes_and_coordinates(data, manager, routing, solution, location_coords, new_waypoints)

    # Create a base map centered around the mean of all coordinates
    map_center = [demand_df['latitude'].mean(), demand_df['longitude'].mean()]
    m = folium.Map(location=map_center, zoom_start=12, tiles='CartoDB Positron')

    # Add depot marker
    # Removed depot marker to prevent confusion based on previous user interaction

    # Define a list of colors for the routes
    colors = ['#FF0000', '#00FF00', '#0000FF', '#FFFF00', '#FF00FF', '#00FFFF', '#800000', '#008000', '#000080', '#808000', '#800080', '#008080', '#C0C0C0', '#808080', '#A52A2A', '#FFA500', '#DDA0DD', '#7FFF00', '#DC143C', '#00CED1']

    # Plot each route
    for i, route_coords in enumerate(all_routes_coords):
        if route_coords:
            folium.PolyLine(route_coords, color=colors[i % len(colors)], weight=2.5, opacity=1).add_to(m)
            # Add markers for each stop in the route (optional, can clutter map)
            for j, coord in enumerate(route_coords):
                # Retrieve depot_coords here for comparison
                depot_coords = location_coords[data['depot']]
                if coord not in new_waypoints and (coord != depot_coords or j == 0):
                    folium.CircleMarker(
                        location=coord,
                        radius=3,
                        color=colors[i % len(colors)],
                        fill=True,
                        fill_color=colors[i % len(colors)],
                        fill_opacity=1,
                        popup=f'Stop {j} on Vehicle {i}'
                    ).add_to(m)

    display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d44254d71396509d361d8a28065b7cfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d44254d71396509d361d8a28065b7cfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d44254d71396509d361d8a28065b7cfc = L.map(
#                 &quot;map_d44254d71396509d361d8a28065b7cfc&quot;,
#                 {
#                     center: [40.726090505954055, -74.0531882697198],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfc57eba06d22924904aa2088e678b03 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfc57eba06d22924904aa2088e678b03.addTo(map_d44254d71396509d361d8a28065b7cfc);
#
#
#             var poly_line_f59560aefa551a6bb7cabea1a1a320fe = L.polyline(
#                 [[40.646567, -74.016319], [40.666659, -73.995811], [40.690608, -74.011917], [40.704701, -74.016795], [40.726184, -74.011653], [40.728652, -74.03156], [40.728652, -74.03156], [40.726184, -74.011653], [40.704701, -74.016795], [40.690608, -74.011917], [40.666659, -73.995811], [40.646567, -74.016319]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_d44254d71396509d361d8a28065b7cfc);
#
#
#             var circle_marker_62cd87deaffba2027cc98ae9a686c0c6 = L.circleMarker(
#                 [40.646567, -74.016319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44254d71396509d361d8a28065b7cfc);
#
#
#         var popup_77df60edd3313b6b224940fe1b43e0fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_648acbf34a1ae67bdc82773a6c370ec6 = $(`&lt;div id=&quot;html_648acbf34a1ae67bdc82773a6c370ec6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stop 0 on Vehicle 0&lt;/div&gt;`)[0];
#                 popup_77df60edd3313b6b224940fe1b43e0fd.setContent(html_648acbf34a1ae67bdc82773a6c370ec6);
#
#
#
#         circle_marker_62cd87deaffba2027cc98ae9a686c0c6.bindPopup(popup_77df60edd3313b6b224940fe1b43e0fd)
#         ;
#
#
#
#
#             var poly_line_f7602104427fa7ef5a6a05de521bbb50 = L.polyline(
#                 [[40.646567, -74.016319], [40.666659, -73.995811], [40.690608, -74.011917], [40.704701, -74.016795], [40.726184, -74.011653], [40.728652, -74.03156], [40.728652, -74.03156], [40.726184, -74.011653], [40.704701, -74.016795], [40.690608, -74.011917], [40.666659, -73.995811], [40.646567, -74.016319]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_d44254d71396509d361d8a28065b7cfc);
#
#
#             var circle_marker_c19cb9691263ade42e2c4a9f69cf7722 = L.circleMarker(
#                 [40.646567, -74.016319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00FF00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &q
