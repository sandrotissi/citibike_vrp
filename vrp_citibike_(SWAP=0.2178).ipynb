# %%
# !pip3 install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.15.6755-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting absl-py>=2.0.0 (from ortools)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.2.2)
# Collecting protobuf<6.34,>=6.33.1 (from ortools)
#   Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from ortools) (4.15.0)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (4.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.17.0)
# Downloading ortools-9.15.6755-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (29.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.8/29.8 MB 63.3 MB/s eta 0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 7.8 MB/s eta 0:00:00
# Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 24.4 MB/s eta 0:00:00
# Installing collected packages: protobuf, absl-py, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.6 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# Successfully installed absl-py-2.4.0 ortools-9.15.6755 protobuf-6.33.6

# %%
import folium

# %%
import pandas as pd

# URL of the distance matrix CSV
url = 'https://raw.githubusercontent.com/sandrotissi/citibike_vrp/226d6d7b050fafc5805837ba8fefe8a65d2c6996/full_distance_matrix_google.csv'

# Read the CSV into a pandas DataFrame
distance_df = pd.read_csv(url, index_col=0)

# Scale distances by 1000 and convert to integers to avoid OR-Tools truncating small floating-point values to 0
new_distance_matrix = [[int(val * 1000) for val in row] for row in distance_df.values.tolist()]

print(f"Loaded a distance matrix of shape: {len(new_distance_matrix)}x{len(new_distance_matrix[0])}")
# Out:
# Loaded a distance matrix of shape: 111x111

# %%
demand_url = 'https://raw.githubusercontent.com/sandrotissi/citibike_vrp/5835068e495eca41dc51875170e7e511b84b8db6/all_archetypes_demand_with_coordinates_swap0.2178.csv'
demand_df = pd.read_csv(demand_url)

# %% [markdown]
# ### Optimization for `demand_001` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_001 = [0] + demand_df['demand_001'].tolist()

def create_data_model_001():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_001]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_001(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0: # Check if the vehicle was actually used
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_001():
    """Solve the CVRP problem."""
    data = create_data_model_001()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_001(data, manager, routing, solution)


if __name__ == '__main__':
    main_001()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  41 Load(3) ->  59 Load(6) ->  72 Load(9) ->  71 Load(13) ->  54 Load(17) ->  110 Load(18) ->  52 Load(20) ->  94 Load(22) ->  95 Load(23) ->  107 Load(24) ->  108 Load(25) ->  82 Load(27) ->  101 Load(28) ->  97 Load(29) ->  98 Load(31) ->  102 Load(32) ->  109 Load(33) ->  103 Load(34) ->  104 Load(35) ->  105 Load(36) ->  106 Load(37) ->  99 Load(38) ->  100 Load(39) ->  96 Load(40) ->  81 Load(41) ->  58 Load(43) ->  92 Load(45) ->  91 Load(47) ->  90 Load(49) ->  93 Load(51) ->  89 Load(52) ->  66 Load(55) ->  84 Load(59) ->  39 Load(65) ->  74 Load(68) -> 0
# Distance of the route: 61821m
# Load of the route: 68
#
# Route for vehicle 9:
#  0 Load(0) ->  44 Load(6) ->  46 Load(11) ->  67 Load(14) ->  56 Load(20) ->  57 Load(23) ->  8 Load(28) ->  7 Load(37) ->  6 Load(44) ->  21 Load(53) ->  31 Load(58) ->  24 Load(59) ->  25 Load(63) ->  22 Load(64) ->  13 Load(71) -> 0
# Distance of the route: 46250m
# Load of the route: 71
#
# Route for vehicle 10:
#  0 Load(0) ->  14 Load(6) ->  18 Load(13) ->  49 Load(18) ->  42 Load(24) ->  78 Load(30) ->  73 Load(34) ->  65 Load(37) ->  70 Load(40) ->  88 Load(45) ->  87 Load(48) ->  53 Load(53) ->  76 Load(56) ->  68 Load(61) ->  38 Load(70) -> 0
# Distance of the route: 45935m
# Load of the route: 70
#
# Route for vehicle 11:
#  0 Load(0) ->  15 Load(8) ->  17 Load(14) ->  29 Load(19) ->  3 Load(27) ->  2 Load(27) ->  30 Load(38) ->  5 Load(56) ->  1 Load(69) -> 0
# Distance of the route: 38129m
# Load of the route: 69
#
# Route for vehicle 12:
#  0 Load(0) ->  47 Load(4) ->  63 Load(9) ->  43 Load(15) ->  55 Load(23) ->  83 Load(35) ->  80 Load(43) ->  33 Load(51) ->  32 Load(57) ->  27 Load(64) ->  4 Load(71) -> 0
# Distance of the route: 45833m
# Load of the route: 71
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(5) ->  60 Load(12) ->  75 Load(17) ->  79 Load(22) ->  86 Load(30) ->  77 Load(36) ->  61 Load(41) ->  51 Load(44) ->  34 Load(48) ->  40 Load(54) ->  36 Load(60) -> 0
# Distance of the route: 41782m
# Load of the route: 60
#
# Route for vehicle 14:
#  0 Load(0) ->  16 Load(4) ->  12 Load(11) ->  10 Load(16) ->  9 Load(23) ->  11 Load(30) ->  20 Load(40) ->  23 Load(47) ->  28 Load(56) ->  26 Load(63) ->  19 Load(68) -> 0
# Distance of the route: 42539m
# Load of the route: 68
#
# Route for vehicle 15:
#  0 Load(0) ->  48 Load(7) ->  69 Load(13) ->  62 Load(17) ->  45 Load(23) ->  64 Load(27) ->  50 Load(32) ->  35 Load(38) ->  85 Load(55) -> 0
# Distance of the route: 39082m
# Load of the route: 55
#
# Total distance driven by all vehicles: 361371m
# Number of vans used: 8

# %% [markdown]
# ### Optimization for `demand_011` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_011 = [0] + demand_df['demand_011'].tolist()

def create_data_model_011():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_011]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_011(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_011():
    """Solve the CVRP problem."""
    data = create_data_model_011()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_011(data, manager, routing, solution)


if __name__ == '__main__':
    main_011()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  14 Load(9) ->  12 Load(19) ->  24 Load(25) ->  8 Load(33) ->  7 Load(46) ->  57 Load(51) ->  56 Load(58) ->  67 Load(63) ->  46 Load(71) -> 0
# Distance of the route: 44885m
# Load of the route: 71
#
# Route for vehicle 7:
#  0 Load(0) ->  74 Load(4) ->  50 Load(10) ->  76 Load(15) ->  87 Load(16) ->  66 Load(22) ->  70 Load(27) ->  91 Load(28) ->  65 Load(33) ->  73 Load(38) ->  71 Load(44) ->  72 Load(48) ->  55 Load(59) ->  43 Load(68) ->  41 Load(72) -> 0
# Distance of the route: 45595m
# Load of the route: 72
#
# Route for vehicle 8:
#  0 Load(0) ->  13 Load(10) ->  21 Load(23) ->  6 Load(35) ->  28 Load(47) ->  62 Load(53) ->  84 Load(60) ->  39 Load(70) -> 0
# Distance of the route: 45597m
# Load of the route: 70
#
# Route for vehicle 9:
#  0 Load(0) ->  42 Load(7) ->  49 Load(13) ->  33 Load(20) ->  1 Load(37) ->  3 Load(48) ->  32 Load(56) ->  27 Load(65) ->  29 Load(71) -> 0
# Distance of the route: 42296m
# Load of the route: 71
#
# Route for vehicle 10:
#  0 Load(0) ->  68 Load(7) ->  63 Load(12) ->  45 Load(20) ->  64 Load(25) ->  35 Load(33) ->  85 Load(55) ->  40 Load(63) ->  36 Load(71) -> 0
# Distance of the route: 39406m
# Load of the route: 71
#
# Route for vehicle 11:
#  0 Load(0) ->  38 Load(13) ->  47 Load(18) ->  69 Load(27) ->  44 Load(36) ->  25 Load(42) ->  22 Load(42) ->  23 Load(50) ->  31 Load(57) ->  20 Load(70) -> 0
# Distance of the route: 44915m
# Load of the route: 70
#
# Route for vehicle 12:
#  0 Load(0) ->  15 Load(10) ->  19 Load(17) ->  4 Load(28) ->  30 Load(42) ->  5 Load(57) ->  2 Load(67) -> 0
# Distance of the route: 37216m
# Load of the route: 67
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(10) ->  60 Load(20) ->  34 Load(26) ->  51 Load(31) ->  61 Load(38) ->  77 Load(45) ->  86 Load(56) ->  79 Load(64) ->  75 Load(71) -> 0
# Distance of the route: 41053m
# Load of the route: 71
#
# Route for vehicle 14:
#  0 Load(0) ->  17 Load(7) ->  26 Load(16) ->  11 Load(25) ->  10 Load(31) ->  9 Load(39) ->  16 Load(46) ->  18 Load(55) ->  80 Load(69) -> 0
# Distance of the route: 40911m
# Load of the route: 69
#
# Route for vehicle 15:
#  0 Load(0) ->  78 Load(8) ->  59 Load(13) ->  83 Load(27) ->  54 Load(33) ->  110 Load(33) ->  52 Load(36) ->  94 Load(37) ->  92 Load(38) ->  90 Load(39) ->  89 Load(40) ->  93 Load(41) ->  81 Load(43) ->  58 Load(46) ->  108 Load(46) ->  95 Load(47) ->  107 Load(47) ->  82 Load(50) ->  101 Load(50) ->  97 Load(50) ->  98 Load(51) ->  102 Load(51) ->  109 Load(51) ->  103 Load(51) ->  104 Load(51) ->  105 Load(51) ->  106 Load(51) ->  99 Load(51) ->  100 Load(51) ->  96 Load(52) ->  88 Load(53) ->  53 Load(63) ->  48 Load(72) -> 0
# Distance of the route: 62435m
# Load of the route: 72
#
# Total distance driven by all vehicles: 444309m
# Number of vans used: 10

# %% [markdown]
# ### Optimization for `demand_101` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_101 = [0] + demand_df['demand_101'].tolist()

def create_data_model_101():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_101]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_101(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_101():
    """Solve the CVRP problem."""
    data = create_data_model_101()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_101(data, manager, routing, solution)


if __name__ == '__main__':
    main_101()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  62 Load(4) ->  69 Load(9) ->  77 Load(13) ->  61 Load(17) ->  51 Load(20) ->  34 Load(22) ->  86 Load(29) ->  79 Load(33) ->  75 Load(37) ->  60 Load(42) ->  37 Load(47) ->  12 Load(53) ->  22 Load(54) ->  25 Load(58) ->  24 Load(59) ->  31 Load(64) ->  13 Load(70) -> 0
# Distance of the route: 48926m
# Load of the route: 70
#
# Route for vehicle 10:
#  0 Load(0) ->  42 Load(5) ->  83 Load(14) ->  59 Load(17) ->  78 Load(21) ->  73 Load(25) ->  65 Load(28) ->  91 Load(30) ->  92 Load(32) ->  90 Load(34) ->  70 Load(37) ->  88 Load(41) ->  87 Load(44) ->  53 Load(49) ->  84 Load(53) ->  50 Load(57) ->  64 Load(60) ->  45 Load(64) ->  63 Load(67) ->  47 Load(70) -> 0
# Distance of the route: 48188m
# Load of the route: 70
#
# Route for vehicle 11:
#  0 Load(0) ->  49 Load(4) ->  46 Load(8) ->  67 Load(10) ->  56 Load(14) ->  57 Load(17) ->  7 Load(25) ->  6 Load(32) ->  28 Load(41) ->  27 Load(46) ->  32 Load(52) ->  29 Load(57) ->  10 Load(61) ->  17 Load(66) ->  15 Load(72) -> 0
# Distance of the route: 47439m
# Load of the route: 72
#
# Route for vehicle 12:
#  0 Load(0) ->  19 Load(5) ->  4 Load(12) ->  33 Load(20) ->  5 Load(34) ->  30 Load(44) ->  2 Load(44) ->  3 Load(52) ->  1 Load(64) -> 0
# Distance of the route: 37485m
# Load of the route: 64
#
# Route for vehicle 13:
#  0 Load(0) ->  68 Load(4) ->  76 Load(7) ->  66 Load(10) ->  89 Load(11) ->  93 Load(13) ->  58 Load(15) ->  81 Load(16) ->  96 Load(17) ->  100 Load(18) ->  99 Load(19) ->  106 Load(20) ->  105 Load(21) ->  104 Load(22) ->  103 Load(23) ->  109 Load(24) ->  102 Load(25) ->  98 Load(27) ->  97 Load(28) ->  101 Load(29) ->  82 Load(31) ->  108 Load(32) ->  107 Load(33) ->  95 Load(34) ->  94 Load(36) ->  52 Load(38) ->  110 Load(39) ->  54 Load(43) ->  71 Load(46) ->  72 Load(49) ->  55 Load(55) ->  43 Load(61) ->  41 Load(64) ->  44 Load(69) -> 0
# Distance of the route: 60664m
# Load of the route: 69
#
# Route for vehicle 14:
#  0 Load(0) ->  14 Load(6) ->  16 Load(9) ->  9 Load(15) ->  11 Load(22) ->  20 Load(30) ->  23 Load(37) ->  8 Load(42) ->  21 Load(51) ->  26 Load(58) ->  18 Load(64) ->  80 Load(71) -> 0
# Distance of the route: 42414m
# Load of the route: 71
#
# Route for vehicle 15:
#  0 Load(0) ->  38 Load(8) ->  48 Load(14) ->  85 Load(27) ->  35 Load(32) ->  74 Load(34) ->  39 Load(40) ->  40 Load(46) ->  36 Load(51) -> 0
# Distance of the route: 39194m
# Load of the route: 51
#
# Total distance driven by all vehicles: 324310m
# Number of vans used: 7

# %% [markdown]
# ### Optimization for `demand_111` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_111 = [0] + demand_df['demand_111'].tolist()

def create_data_model_111():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_111]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_111(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_111():
    """Solve the CVRP problem."""
    data = create_data_model_111()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_111(data, manager, routing, solution)


if __name__ == '__main__':
    main_111()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  1 Load(16) ->  2 Load(23) ->  3 Load(36) ->  32 Load(45) ->  27 Load(52) ->  29 Load(59) -> 0
# Distance of the route: 38546m
# Load of the route: 59
#
# Route for vehicle 7:
#  0 Load(0) ->  49 Load(6) ->  44 Load(13) ->  46 Load(20) ->  67 Load(25) ->  56 Load(32) ->  57 Load(36) ->  7 Load(49) ->  8 Load(57) ->  23 Load(64) ->  9 Load(71) -> 0
# Distance of the route: 44968m
# Load of the route: 71
#
# Route for vehicle 8:
#  0 Load(0) ->  35 Load(7) ->  50 Load(13) ->  84 Load(20) ->  106 Load(20) ->  105 Load(20) ->  104 Load(20) ->  103 Load(20) ->  109 Load(20) ->  102 Load(20) ->  98 Load(21) ->  97 Load(21) ->  101 Load(21) ->  99 Load(21) ->  100 Load(21) ->  96 Load(22) ->  81 Load(24) ->  58 Load(27) ->  108 Load(27) ->  82 Load(30) ->  107 Load(30) ->  95 Load(31) ->  94 Load(32) ->  52 Load(35) ->  110 Load(35) ->  54 Load(42) ->  91 Load(43) ->  92 Load(44) ->  90 Load(45) ->  93 Load(46) ->  89 Load(47) ->  70 Load(52) ->  88 Load(53) ->  87 Load(55) ->  53 Load(68) ->  74 Load(72) -> 0
# Distance of the route: 64241m
# Load of the route: 72
#
# Route for vehicle 9:
#  0 Load(0) ->  15 Load(8) ->  17 Load(15) ->  26 Load(24) ->  11 Load(32) ->  20 Load(42) ->  13 Load(51) ->  12 Load(58) ->  16 Load(64) ->  14 Load(72) -> 0
# Distance of the route: 39362m
# Load of the route: 72
#
# Route for vehicle 10:
#  0 Load(0) ->  41 Load(4) ->  59 Load(8) ->  83 Load(20) ->  71 Load(25) ->  72 Load(28) ->  55 Load(36) ->  43 Load(44) ->  66 Load(50) ->  65 Load(55) ->  73 Load(60) ->  78 Load(65) ->  42 Load(72) -> 0
# Distance of the route: 46717m
# Load of the route: 72
#
# Route for vehicle 11:
#  0 Load(0) ->  18 Load(8) ->  22 Load(8) ->  25 Load(14) ->  24 Load(19) ->  31 Load(26) ->  21 Load(39) ->  6 Load(51) ->  28 Load(61) ->  10 Load(66) ->  19 Load(72) -> 0
# Distance of the route: 42918m
# Load of the route: 72
#
# Route for vehicle 12:
#  0 Load(0) ->  4 Load(10) ->  30 Load(21) ->  5 Load(34) ->  33 Load(43) ->  80 Load(57) -> 0
# Distance of the route: 37596m
# Load of the route: 57
#
# Route for vehicle 13:
#  0 Load(0) ->  85 Load(21) ->  39 Load(31) ->  40 Load(39) ->  36 Load(48) -> 0
# Distance of the route: 38325m
# Load of the route: 48
#
# Route for vehicle 14:
#  0 Load(0) ->  75 Load(8) ->  79 Load(15) ->  86 Load(27) ->  77 Load(33) ->  61 Load(39) ->  51 Load(44) ->  34 Load(49) ->  60 Load(58) ->  37 Load(69) -> 0
# Distance of the route: 41053m
# Load of the route: 69
#
# Route for vehicle 15:
#  0 Load(0) ->  38 Load(13) ->  68 Load(18) ->  63 Load(22) ->  45 Load(30) ->  76 Load(34) ->  64 Load(38) ->  48 Load(48) ->  69 Load(56) ->  62 Load(62) ->  47 Load(67) -> 0
# Distance of the route: 39493m
# Load of the route: 67
#
# Total distance driven by all vehicles: 433219m
# Number of vans used: 10

# %% [markdown]
# ### Optimization for `demand_100` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_100 = [0] + demand_df['demand_100'].tolist()

def create_data_model_100():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_100]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_100(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_100():
    """Solve the CVRP problem."""
    data = create_data_model_100()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_100(data, manager, routing, solution)


if __name__ == '__main__':
    main_100()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  49 Load(4) ->  44 Load(10) ->  46 Load(15) ->  67 Load(17) ->  56 Load(21) ->  57 Load(24) ->  7 Load(32) ->  6 Load(38) ->  28 Load(46) ->  27 Load(50) ->  32 Load(57) ->  3 Load(64) ->  2 Load(64) -> 0
# Distance of the route: 45511m
# Load of the route: 64
#
# Route for vehicle 10:
#  0 Load(0) ->  42 Load(4) ->  78 Load(8) ->  55 Load(16) ->  43 Load(22) ->  73 Load(26) ->  65 Load(29) ->  91 Load(31) ->  70 Load(34) ->  66 Load(38) ->  88 Load(43) ->  87 Load(46) ->  53 Load(52) ->  50 Load(55) ->  48 Load(61) ->  69 Load(67) -> 0
# Distance of the route: 44726m
# Load of the route: 67
#
# Route for vehicle 11:
#  0 Load(0) ->  14 Load(6) ->  16 Load(9) ->  9 Load(15) ->  10 Load(19) ->  12 Load(25) ->  13 Load(30) ->  20 Load(38) ->  11 Load(46) ->  26 Load(53) ->  19 Load(57) -> 0
# Distance of the route: 40427m
# Load of the route: 57
#
# Route for vehicle 12:
#  0 Load(0) ->  15 Load(9) ->  17 Load(15) ->  29 Load(20) ->  4 Load(26) ->  33 Load(33) ->  30 Load(42) ->  5 Load(55) ->  1 Load(68) -> 0
# Distance of the route: 38027m
# Load of the route: 68
#
# Route for vehicle 13:
#  0 Load(0) ->  47 Load(4) ->  62 Load(8) ->  84 Load(11) ->  90 Load(14) ->  89 Load(15) ->  93 Load(17) ->  96 Load(18) ->  100 Load(19) ->  99 Load(20) ->  106 Load(21) ->  105 Load(22) ->  104 Load(23) ->  101 Load(24) ->  103 Load(24) ->  109 Load(25) ->  102 Load(26) ->  98 Load(28) ->  97 Load(28) ->  107 Load(29) ->  82 Load(30) ->  108 Load(31) ->  81 Load(32) ->  58 Load(35) ->  92 Load(36) ->  95 Load(37) ->  94 Load(39) ->  52 Load(41) ->  110 Load(42) ->  54 Load(46) ->  72 Load(48) ->  71 Load(51) ->  83 Load(61) ->  59 Load(64) ->  41 Load(68) -> 0
# Distance of the route: 62336m
# Load of the route: 68
#
# Route for vehicle 14:
#  0 Load(0) ->  38 Load(9) ->  68 Load(13) ->  76 Load(16) ->  64 Load(19) ->  45 Load(26) ->  63 Load(30) ->  80 Load(38) ->  18 Load(42) ->  22 Load(43) ->  25 Load(46) ->  24 Load(47) ->  8 Load(51) ->  21 Load(61) ->  23 Load(68) ->  31 Load(72) -> 0
# Distance of the route: 47108m
# Load of the route: 72
#
# Route for vehicle 15:
#  0 Load(0) ->  37 Load(5) ->  60 Load(10) ->  75 Load(13) ->  36 Load(18) ->  79 Load(21) ->  86 Load(27) ->  77 Load(31) ->  61 Load(35) ->  51 Load(37) ->  34 Load(40) ->  40 Load(46) ->  39 Load(51) ->  74 Load(53) ->  35 Load(57) ->  85 Load(70) -> 0
# Distance of the route: 44050m
# Load of the route: 70
#
# Total distance driven by all vehicles: 322185m
# Number of vans used: 7

# %% [markdown]
# ### Optimization for `demand_110` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_110 = [0] + demand_df['demand_110'].tolist()

def create_data_model_110():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_110]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_110(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_110():
    """Solve the CVRP problem."""
    data = create_data_model_110()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_110(data, manager, routing, solution)


if __name__ == '__main__':
    main_110()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  49 Load(5) ->  44 Load(10) ->  29 Load(15) ->  28 Load(24) ->  27 Load(30) ->  33 Load(36) ->  30 Load(45) ->  5 Load(53) ->  2 Load(64) ->  3 Load(71) -> 0
# Distance of the route: 42658m
# Load of the route: 71
#
# Route for vehicle 8:
#  0 Load(0) ->  40 Load(7) ->  74 Load(10) ->  39 Load(20) ->  53 Load(30) ->  87 Load(31) ->  88 Load(32) ->  66 Load(37) ->  70 Load(41) ->  89 Load(41) ->  90 Load(42) ->  43 Load(50) ->  55 Load(57) ->  83 Load(68) ->  59 Load(72) -> 0
# Distance of the route: 47015m
# Load of the route: 72
#
# Route for vehicle 9:
#  0 Load(0) ->  42 Load(6) ->  78 Load(11) ->  73 Load(16) ->  65 Load(20) ->  91 Load(21) ->  92 Load(22) ->  58 Load(25) ->  81 Load(27) ->  93 Load(28) ->  96 Load(28) ->  100 Load(28) ->  99 Load(28) ->  106 Load(28) ->  105 Load(28) ->  104 Load(28) ->  103 Load(28) ->  109 Load(28) ->  102 Load(28) ->  98 Load(28) ->  97 Load(28) ->  101 Load(28) ->  82 Load(31) ->  108 Load(31) ->  107 Load(31) ->  95 Load(32) ->  94 Load(33) ->  52 Load(36) ->  110 Load(36) ->  54 Load(42) ->  71 Load(47) ->  72 Load(49) ->  35 Load(55) ->  85 Load(72) -> 0
# Distance of the route: 60593m
# Load of the route: 72
#
# Route for vehicle 10:
#  0 Load(0) ->  80 Load(13) -> 0
# Distance of the route: 34888m
# Load of the route: 13
#
# Route for vehicle 11:
#  0 Load(0) ->  41 Load(3) ->  67 Load(8) ->  46 Load(13) ->  56 Load(19) ->  57 Load(24) ->  8 Load(31) ->  7 Load(43) ->  6 Load(52) ->  21 Load(62) ->  4 Load(72) -> 0
# Distance of the route: 44986m
# Load of the route: 72
#
# Route for vehicle 12:
#  0 Load(0) ->  18 Load(9) ->  16 Load(16) ->  12 Load(23) ->  13 Load(31) ->  22 Load(31) ->  25 Load(36) ->  24 Load(42) ->  31 Load(47) ->  10 Load(52) ->  19 Load(58) ->  15 Load(67) -> 0
# Distance of the route: 42081m
# Load of the route: 67
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(9) ->  60 Load(18) ->  75 Load(24) ->  79 Load(30) ->  86 Load(41) ->  34 Load(46) ->  51 Load(49) ->  61 Load(55) ->  77 Load(60) ->  36 Load(68) -> 0
# Distance of the route: 41211m
# Load of the route: 68
#
# Route for vehicle 14:
#  0 Load(0) ->  1 Load(15) ->  32 Load(23) ->  26 Load(31) ->  23 Load(37) ->  20 Load(46) ->  11 Load(54) ->  9 Load(60) ->  17 Load(66) ->  14 Load(72) -> 0
# Distance of the route: 41167m
# Load of the route: 72
#
# Route for vehicle 15:
#  0 Load(0) ->  38 Load(12) ->  68 Load(18) ->  63 Load(21) ->  45 Load(27) ->  64 Load(31) ->  76 Load(35) ->  84 Load(41) ->  50 Load(47) ->  48 Load(56) ->  69 Load(62) ->  62 Load(67) ->  47 Load(71) -> 0
# Distance of the route: 40160m
# Load of the route: 71
#
# Total distance driven by all vehicles: 394759m
# Number of vans used: 9

# %% [markdown]
# ### Optimization for `demand_010` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_010 = [0] + demand_df['demand_010'].tolist()

def create_data_model_010():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_010]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_010(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_010():
    """Solve the CVRP problem."""
    data = create_data_model_010()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_010(data, manager, routing, solution)


if __name__ == '__main__':
    main_010()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  41 Load(3) ->  78 Load(10) ->  59 Load(14) ->  72 Load(18) ->  54 Load(24) ->  110 Load(24) ->  52 Load(27) ->  94 Load(28) ->  107 Load(28) ->  95 Load(29) ->  92 Load(30) ->  58 Load(33) ->  81 Load(35) ->  108 Load(35) ->  82 Load(37) ->  101 Load(37) ->  97 Load(37) ->  98 Load(38) ->  102 Load(38) ->  109 Load(38) ->  103 Load(38) ->  104 Load(38) ->  105 Load(38) ->  106 Load(38) ->  99 Load(38) ->  100 Load(38) ->  96 Load(39) ->  93 Load(40) ->  89 Load(41) ->  90 Load(42) ->  91 Load(43) ->  65 Load(48) ->  73 Load(53) ->  43 Load(61) ->  64 Load(66) ->  68 Load(72) -> 0
# Distance of the route: 62794m
# Load of the route: 72
#
# Route for vehicle 8:
#  0 Load(0) ->  62 Load(5) ->  85 Load(25) ->  39 Load(34) ->  74 Load(38) ->  71 Load(44) ->  55 Load(53) ->  83 Load(66) ->  42 Load(72) -> 0
# Distance of the route: 43363m
# Load of the route: 72
#
# Route for vehicle 9:
#  0 Load(0) ->  47 Load(5) ->  69 Load(12) ->  48 Load(19) ->  84 Load(25) ->  76 Load(29) ->  66 Load(35) ->  70 Load(40) ->  88 Load(41) ->  87 Load(42) ->  53 Load(51) ->  50 Load(57) ->  35 Load(63) ->  36 Load(70) -> 0
# Distance of the route: 43973m
# Load of the route: 70
#
# Route for vehicle 10:
#  0 Load(0) ->  10 Load(6) ->  31 Load(11) ->  23 Load(18) ->  21 Load(30) ->  27 Load(38) ->  32 Load(45) ->  3 Load(54) ->  1 Load(70) -> 0
# Distance of the route: 42084m
# Load of the route: 70
#
# Route for vehicle 11:
#  0 Load(0) ->  33 Load(8) ->  28 Load(19) ->  6 Load(28) ->  7 Load(41) ->  8 Load(48) ->  24 Load(55) ->  25 Load(61) ->  22 Load(61) ->  13 Load(70) -> 0
# Distance of the route: 41737m
# Load of the route: 70
#
# Route for vehicle 12:
#  0 Load(0) ->  15 Load(10) ->  17 Load(16) ->  29 Load(21) ->  4 Load(31) ->  30 Load(43) ->  5 Load(56) ->  2 Load(65) ->  19 Load(71) -> 0
# Distance of the route: 38206m
# Load of the route: 71
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(8) ->  60 Load(16) ->  75 Load(22) ->  79 Load(28) ->  86 Load(38) ->  77 Load(44) ->  61 Load(51) ->  51 Load(55) ->  34 Load(61) ->  40 Load(68) -> 0
# Distance of the route: 41396m
# Load of the route: 68
#
# Route for vehicle 14:
#  0 Load(0) ->  14 Load(8) ->  16 Load(15) ->  12 Load(24) ->  20 Load(35) ->  11 Load(43) ->  26 Load(51) ->  9 Load(58) ->  80 Load(71) -> 0
# Distance of the route: 39946m
# Load of the route: 71
#
# Route for vehicle 15:
#  0 Load(0) ->  18 Load(9) ->  57 Load(14) ->  56 Load(21) ->  67 Load(26) ->  46 Load(33) ->  44 Load(41) ->  49 Load(47) ->  45 Load(54) ->  63 Load(59) ->  38 Load(71) -> 0
# Distance of the route: 44146m
# Load of the route: 71
#
# Total distance driven by all vehicles: 397645m
# Number of vans used: 9

# %% [markdown]
# ### Optimization for `demand_000` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_000 = [0] + demand_df['demand_000'].tolist()

def create_data_model_000():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_000]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_000(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_000():
    """Solve the CVRP problem."""
    data = create_data_model_000()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_000(data, manager, routing, solution)


if __name__ == '__main__':
    main_000()
# Out:
# Route for vehicle 0:
#  0 Load(0) ->  37 Load(5) ->  60 Load(12) ->  75 Load(16) ->  79 Load(21) ->  86 Load(29) ->  34 Load(33) ->  51 Load(36) ->  61 Load(41) ->  77 Load(46) ->  36 Load(51) ->  40 Load(57) ->  48 Load(63) ->  38 Load(71) -> 0
# Distance of the route: 42782m
# Load of the route: 71
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  9 Load(7) ->  10 Load(12) ->  26 Load(19) ->  11 Load(25) ->  20 Load(34) ->  31 Load(39) ->  24 Load(40) ->  8 Load(45) ->  6 Load(53) ->  21 Load(62) ->  23 Load(68) ->  57 Load(71) -> 0
# Distance of the route: 44579m
# Load of the route: 71
#
# Route for vehicle 10:
#  0 Load(0) ->  16 Load(3) ->  12 Load(9) ->  13 Load(16) ->  22 Load(17) ->  25 Load(20) ->  87 Load(23) ->  53 Load(28) ->  88 Load(32) ->  66 Load(35) ->  70 Load(38) ->  89 Load(39) ->  93 Load(41) ->  104 Load(42) ->  101 Load(43) ->  82 Load(44) ->  108 Load(45) ->  81 Load(46) ->  58 Load(48) ->  92 Load(50) ->  91 Load(53) ->  71 Load(57) ->  83 Load(68) ->  41 Load(71) -> 0
# Distance of the route: 56324m
# Load of the route: 71
#
# Route for vehicle 11:
#  0 Load(0) ->  42 Load(6) ->  78 Load(12) ->  55 Load(19) ->  43 Load(24) ->  73 Load(28) ->  65 Load(31) ->  90 Load(33) ->  96 Load(34) ->  100 Load(35) ->  99 Load(36) ->  106 Load(37) ->  105 Load(38) ->  103 Load(39) ->  109 Load(40) ->  102 Load(41) ->  98 Load(43) ->  97 Load(44) ->  107 Load(45) ->  95 Load(46) ->  94 Load(48) ->  52 Load(50) ->  110 Load(51) ->  54 Load(55) ->  72 Load(58) ->  59 Load(61) ->  44 Load(68) ->  49 Load(72) -> 0
# Distance of the route: 58041m
# Load of the route: 72
#
# Route for vehicle 12:
#  0 Load(0) ->  80 Load(7) ->  15 Load(14) ->  17 Load(19) ->  4 Load(26) ->  33 Load(34) ->  30 Load(43) ->  5 Load(59) ->  2 Load(59) ->  1 Load(71) -> 0
# Distance of the route: 38651m
# Load of the route: 71
#
# Route for vehicle 13:
#  0 Load(0) ->  47 Load(4) ->  62 Load(8) ->  69 Load(14) ->  74 Load(17) ->  39 Load(23) ->  85 Load(37) ->  35 Load(42) ->  50 Load(46) ->  84 Load(50) ->  76 Load(53) ->  64 Load(56) ->  45 Load(62) ->  63 Load(66) ->  68 Load(70) -> 0
# Distance of the route: 41622m
# Load of the route: 70
#
# Route for vehicle 14:
#  0 Load(0) ->  19 Load(5) ->  29 Load(9) ->  3 Load(17) ->  32 Load(22) ->  27 Load(29) ->  28 Load(38) ->  7 Load(47) ->  56 Load(52) ->  67 Load(55) ->  46 Load(60) ->  18 Load(66) ->  14 Load(71) -> 0
# Distance of the route: 46512m
# Load of the route: 71
#
# Route for vehicle 15:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Total distance driven by all vehicles: 328511m
# Number of vans used: 7

# %%
import folium

def get_routes_and_coordinates(data, manager, routing, solution, location_coords, new_waypoints):
    """Extracts routes and corresponding coordinates."""
    all_routes_coords = []

    for vehicle_id in range(data['num_vehicles']):
        route_coords = []
        index = routing.Start(vehicle_id) # This `index` is the depot's internal OR-Tools index

        # 1. Add the depot as the starting point
        depot_node_idx = manager.IndexToNode(index)
        depot_coords = location_coords[depot_node_idx]
        route_coords.append(depot_coords)

        # 2. Add the new waypoints immediately after the depot for visualization (outbound)
        route_coords.extend(new_waypoints)

        # 3. Traverse the OR-Tools solution to get all actual stops
        actual_stops_coords = []
        current_route_index = index
        current_route_index = solution.Value(routing.NextVar(current_route_index))

        while not routing.IsEnd(current_route_index):
            node_index = manager.IndexToNode(current_route_index)
            actual_stops_coords.append(location_coords[node_index])
            current_route_index = solution.Value(routing.NextVar(current_route_index))

        route_coords.extend(actual_stops_coords)

        # 4. Add the new waypoints before returning to the depot (inbound)
        # It's more realistic to traverse them in reverse order
        route_coords.extend(list(reversed(new_waypoints)))

        # 5. Add the final depot coordinate
        # The OR-Tools solution implicitly ends at the depot, so we'll just add the depot coords.
        route_coords.append(depot_coords)

        all_routes_coords.append(route_coords)

    return all_routes_coords

# Re-run main to get the solution object for demand_000
data = create_data_model_000()
manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                       data['num_vehicles'], data['depot'])
routing = pywrapcp.RoutingModel(manager)

# Create and register a transit callback (same as in main)
def distance_callback(from_index, to_index):
    return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]
transit_callback_index = routing.RegisterTransitCallback(distance_callback)
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# Add Capacity constraint (same as in main)
def demand_callback(from_index):
    return data['demands'][manager.IndexToNode(from_index)]
demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
routing.AddDimensionWithVehicleCapacity(
    demand_callback_index,
    0,  # null capacity slack
    data['vehicle_capacities'],  # vehicle maximum capacities
    True,  # start cumul to zero
    'Capacity')

search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

solution = routing.SolveWithParameters(search_parameters)

if solution:
    location_coords = {}
    # Get coordinates for all stations from demand_df (node_index 1 corresponds to first row of demand_df)
    for idx, row in demand_df.iterrows():
        # demand_df has 110 rows, corresponding to nodes 1-110
        # idx in demand_df corresponds to node_index = idx + 1
        location_coords[idx + 1] = (row['latitude'], row['longitude'])

    # Add the depot (index 0) with the user-provided coordinates
    depot_lat = 40.646567
    depot_lon = -74.016319
    location_coords[0] = (depot_lat, depot_lon)

    # Define the new waypoints for visualization only (moved outside the function)
    new_waypoints = [
        (40.666659, -73.995811),
        (40.690608, -74.011917),
        (40.704701, -74.016795),
        (40.726184, -74.011653),
        (40.728652, -74.031560)
    ]

    all_routes_coords = get_routes_and_coordinates(data, manager, routing, solution, location_coords, new_waypoints)

    # Create a base map centered around the mean of all coordinates
    map_center = [demand_df['latitude'].mean(), demand_df['longitude'].mean()]
    m = folium.Map(location=map_center, zoom_start=12, tiles='CartoDB Positron')

    # Add depot marker
    # Removed depot marker to prevent confusion based on previous user interaction

    # Define a list of colors for the routes
    colors = ['#FF0000', '#00FF00', '#0000FF', '#FFFF00', '#FF00FF', '#00FFFF', '#800000', '#008000', '#000080', '#808000', '#800080', '#008080', '#C0C0C0', '#808080', '#A52A2A', '#FFA500', '#DDA0DD', '#7FFF00', '#DC143C', '#00CED1']

    # Plot each route
    for i, route_coords in enumerate(all_routes_coords):
        if route_coords:
            folium.PolyLine(route_coords, color=colors[i % len(colors)], weight=2.5, opacity=1).add_to(m)
            # Add markers for each stop in the route (optional, can clutter map)
            for j, coord in enumerate(route_coords):
                # Retrieve depot_coords here for comparison
                depot_coords = location_coords[data['depot']]
                if coord not in new_waypoints and (coord != depot_coords or j == 0):
                    folium.CircleMarker(
                        location=coord,
                        radius=3,
                        color=colors[i % len(colors)],
                        fill=True,
                        fill_color=colors[i % len(colors)],
                        fill_opacity=1,
                        popup=f'Stop {j} on Vehicle {i}'
                    ).add_to(m)

    display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16d08ce1d992958d36759fbae6ce2330 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16d08ce1d992958d36759fbae6ce2330&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16d08ce1d992958d36759fbae6ce2330 = L.map(
#                 &quot;map_16d08ce1d992958d36759fbae6ce2330&quot;,
#                 {
#                     center: [40.726090505954055, -74.0531882697198],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da7194117d5b115ef57686f20284d3bf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da7194117d5b115ef57686f20284d3bf.addTo(map_16d08ce1d992958d36759fbae6ce2330);
#
#
#             var poly_line_96dcba2d610b016882692794d0857c16 = L.polyline(
#                 [[40.646567, -74.016319], [40.666659, -73.995811], [40.690608, -74.011917], [40.704701, -74.016795], [40.726184, -74.011653], [40.728652, -74.03156], [40.7287448, -74.0321082], [40.7272235, -74.0337589], [40.7242941, -74.0354826], [40.7192517, -74.034234], [40.71636596185077, -74.034343957901], [40.7141454, -74.0335519], [40.7127742, -74.0364857], [40.7124188237569, -74.03852552175522], [40.71517767732029, -74.03768330812454], [40.7211236, -74.03805095], [40.71835519823214, -74.03891444206238], [40.72152515, -74.046304543], [40.727595966, -74.044247311], [40.728652, -74.03156], [40.726184, -74.011653], [40.704701, -74.016795], [40.690608, -74.011917], [40.666659, -73.995811], [40.646567, -74.016319]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_16d08ce1d992958d36759fbae6ce2330);
#
#
#             var circle_marker_88e03284fcfff8f747b0d39510f8fee3 = L.circleMarker(
#                 [40.646567, -74.016319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_16d08ce1d992958d36759fbae6ce2330);
#
#
#         var popup_425ca1e0596a867fe2f074aa173a1cf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd002aa618a0cbd80c25e0cbe72c8139 = $(`&lt;div id=&quot;html_cd002aa618a0cbd80c25e0cbe72c8139&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stop 0 on Vehicle 0&lt;/div&gt;`)[0];
#                 popup_425ca1e0596a867fe2f074aa173a1cf3.setContent(html_cd002aa618a0cbd80c25e0cbe72c8139);
#
#
#
#         circle_marker_88e03284fcfff8f747b0d39510f8fee3.bindPopup(popup_425ca1e0596a867fe2f074aa173a1cf3)
#         ;
#
#
#
#
#             var circle_marker_eaf69e3ea601deb8dd2a0c05ec62c0d7 = L.circleMarker(
#                 [40.7287448, -74.0321082],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_16d08ce1d992958d36759fbae6ce2330);
#
#
#         var popup_3398280ea4d02d5bae01e141414e5dbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd9a947cd1a27ccbd06efdb922dee681 = $(`&lt;div id=&quot;html_fd9a947cd1a27ccbd06efdb922dee681&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stop 6 on Vehicle 0&lt;/div&gt;`)[0];
#                 popup_3398280ea4d02d5bae01e141414e5dbd.setContent(html_
