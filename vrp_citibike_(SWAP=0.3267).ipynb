# %%
# !pip3 install ortools
# Out:
# Requirement already satisfied: ortools in /usr/local/lib/python3.12/dist-packages (9.15.6755)
# Requirement already satisfied: absl-py>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.4.0)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.2.2)
# Requirement already satisfied: protobuf<6.34,>=6.33.1 in /usr/local/lib/python3.12/dist-packages (from ortools) (6.33.6)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from ortools) (4.15.0)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (4.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->ortools) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.17.0)

# %%
import folium

# %%
import pandas as pd

# URL of the distance matrix CSV
url = 'https://raw.githubusercontent.com/sandrotissi/citibike_vrp/226d6d7b050fafc5805837ba8fefe8a65d2c6996/full_distance_matrix_google.csv'

# Read the CSV into a pandas DataFrame
distance_df = pd.read_csv(url, index_col=0)

# Scale distances by 1000 and convert to integers to avoid OR-Tools truncating small floating-point values to 0
new_distance_matrix = [[int(val * 1000) for val in row] for row in distance_df.values.tolist()]

print(f"Loaded a distance matrix of shape: {len(new_distance_matrix)}x{len(new_distance_matrix[0])}")
# Out:
# Loaded a distance matrix of shape: 111x111

# %%
demand_url = 'https://raw.githubusercontent.com/sandrotissi/citibike_vrp/e72b84e218bd17f064948623c0d6d70887f32934/all_archetypes_demand_with_coordinates.csv'
demand_df = pd.read_csv(demand_url)

# %% [markdown]
# ### Optimization for `demand_001` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_001 = [0] + demand_df['demand_001'].tolist()

def create_data_model_001():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_001]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_001(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0: # Check if the vehicle was actually used
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_001():
    """Solve the CVRP problem."""
    data = create_data_model_001()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_001(data, manager, routing, solution)


if __name__ == '__main__':
    main_001()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  49 Load(6) ->  44 Load(14) ->  46 Load(20) ->  67 Load(23) ->  56 Load(30) ->  23 Load(39) ->  21 Load(52) ->  10 Load(58) ->  12 Load(67) ->  16 Load(72) -> 0
# Distance of the route: 44906m
# Load of the route: 72
#
# Route for vehicle 7:
#  0 Load(0) ->  41 Load(3) ->  59 Load(7) ->  72 Load(11) ->  54 Load(16) ->  110 Load(17) ->  52 Load(19) ->  94 Load(21) ->  95 Load(22) ->  107 Load(23) ->  108 Load(24) ->  82 Load(26) ->  101 Load(27) ->  97 Load(28) ->  98 Load(30) ->  102 Load(31) ->  109 Load(32) ->  103 Load(33) ->  104 Load(34) ->  105 Load(35) ->  106 Load(36) ->  99 Load(37) ->  100 Load(38) ->  96 Load(39) ->  81 Load(40) ->  58 Load(42) ->  92 Load(44) ->  91 Load(46) ->  71 Load(51) ->  78 Load(58) ->  42 Load(66) -> 0
# Distance of the route: 59509m
# Load of the route: 66
#
# Route for vehicle 8:
#  0 Load(0) ->  74 Load(4) ->  53 Load(10) ->  87 Load(14) ->  88 Load(20) ->  66 Load(24) ->  70 Load(28) ->  89 Load(29) ->  93 Load(31) ->  90 Load(34) ->  65 Load(38) ->  73 Load(43) ->  76 Load(47) ->  84 Load(52) ->  39 Load(60) ->  40 Load(68) -> 0
# Distance of the route: 47465m
# Load of the route: 68
#
# Route for vehicle 9:
#  0 Load(0) ->  47 Load(4) ->  62 Load(9) ->  69 Load(17) ->  48 Load(25) ->  50 Load(31) ->  35 Load(39) ->  85 Load(63) -> 0
# Distance of the route: 38107m
# Load of the route: 63
#
# Route for vehicle 10:
#  0 Load(0) ->  32 Load(8) ->  27 Load(17) ->  28 Load(29) ->  6 Load(39) ->  7 Load(51) ->  8 Load(57) ->  57 Load(61) ->  18 Load(70) -> 0
# Distance of the route: 42928m
# Load of the route: 70
#
# Route for vehicle 11:
#  0 Load(0) ->  19 Load(7) ->  4 Load(17) ->  33 Load(27) ->  5 Load(52) ->  30 Load(66) -> 0
# Distance of the route: 37064m
# Load of the route: 66
#
# Route for vehicle 12:
#  0 Load(0) ->  80 Load(11) ->  15 Load(21) ->  17 Load(28) ->  29 Load(34) ->  3 Load(44) ->  2 Load(44) ->  1 Load(62) -> 0
# Distance of the route: 38713m
# Load of the route: 62
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(7) ->  60 Load(17) ->  75 Load(24) ->  79 Load(30) ->  86 Load(41) ->  34 Load(46) ->  51 Load(50) ->  61 Load(56) ->  77 Load(63) ->  36 Load(70) -> 0
# Distance of the route: 41211m
# Load of the route: 70
#
# Route for vehicle 14:
#  0 Load(0) ->  14 Load(8) ->  9 Load(17) ->  26 Load(26) ->  11 Load(35) ->  20 Load(48) ->  31 Load(54) ->  24 Load(55) ->  25 Load(60) ->  22 Load(61) ->  13 Load(71) -> 0
# Distance of the route: 41213m
# Load of the route: 71
#
# Route for vehicle 15:
#  0 Load(0) ->  83 Load(16) ->  55 Load(26) ->  43 Load(33) ->  64 Load(37) ->  45 Load(45) ->  63 Load(51) ->  68 Load(57) ->  38 Load(69) -> 0
# Distance of the route: 41469m
# Load of the route: 69
#
# Total distance driven by all vehicles: 432585m
# Number of vans used: 10

# %% [markdown]
# ### Optimization for `demand_011` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_011 = [0] + demand_df['demand_011'].tolist()

def create_data_model_011():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_011]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_011(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_011():
    """Solve the CVRP problem."""
    data = create_data_model_011()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_011(data, manager, routing, solution)


if __name__ == '__main__':
    main_011()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  17 Load(9) ->  31 Load(18) ->  24 Load(25) ->  8 Load(35) ->  7 Load(54) ->  6 Load(70) -> 0
# Distance of the route: 41506m
# Load of the route: 70
#
# Route for vehicle 3:
#  0 Load(0) ->  35 Load(10) ->  53 Load(23) ->  87 Load(24) ->  88 Load(26) ->  66 Load(34) ->  70 Load(41) ->  89 Load(42) ->  93 Load(43) ->  90 Load(44) ->  91 Load(45) ->  65 Load(51) ->  73 Load(58) ->  78 Load(70) -> 0
# Distance of the route: 45368m
# Load of the route: 70
#
# Route for vehicle 4:
#  0 Load(0) ->  9 Load(11) ->  11 Load(23) ->  20 Load(40) ->  23 Load(51) ->  26 Load(63) ->  29 Load(71) -> 0
# Distance of the route: 39983m
# Load of the route: 71
#
# Route for vehicle 5:
#  0 Load(0) ->  68 Load(9) ->  76 Load(15) ->  84 Load(23) ->  92 Load(24) ->  58 Load(28) ->  81 Load(30) ->  96 Load(31) ->  100 Load(31) ->  99 Load(31) ->  106 Load(31) ->  105 Load(31) ->  104 Load(31) ->  103 Load(31) ->  109 Load(31) ->  102 Load(31) ->  98 Load(32) ->  97 Load(32) ->  101 Load(32) ->  82 Load(35) ->  108 Load(35) ->  107 Load(35) ->  95 Load(36) ->  94 Load(37) ->  52 Load(41) ->  110 Load(41) ->  54 Load(49) ->  71 Load(56) ->  72 Load(61) ->  59 Load(67) ->  41 Load(72) -> 0
# Distance of the route: 60119m
# Load of the route: 72
#
# Route for vehicle 6:
#  0 Load(0) ->  3 Load(14) ->  32 Load(25) ->  27 Load(38) ->  28 Load(54) ->  21 Load(71) -> 0
# Distance of the route: 40693m
# Load of the route: 71
#
# Route for vehicle 7:
#  0 Load(0) ->  42 Load(9) ->  43 Load(21) ->  55 Load(35) ->  83 Load(55) -> 0
# Distance of the route: 40200m
# Load of the route: 55
#
# Route for vehicle 8:
#  0 Load(0) ->  74 Load(5) ->  39 Load(18) ->  77 Load(28) ->  61 Load(37) ->  34 Load(46) ->  40 Load(57) ->  36 Load(68) -> 0
# Distance of the route: 39575m
# Load of the route: 68
#
# Route for vehicle 9:
#  0 Load(0) ->  30 Load(19) ->  5 Load(41) ->  33 Load(51) ->  4 Load(67) -> 0
# Distance of the route: 36720m
# Load of the route: 67
#
# Route for vehicle 10:
#  0 Load(0) ->  47 Load(6) ->  63 Load(13) ->  45 Load(24) ->  64 Load(30) ->  50 Load(38) ->  85 Load(70) -> 0
# Distance of the route: 38318m
# Load of the route: 70
#
# Route for vehicle 11:
#  0 Load(0) ->  49 Load(8) ->  44 Load(19) ->  46 Load(29) ->  67 Load(35) ->  56 Load(44) ->  57 Load(50) ->  80 Load(70) -> 0
# Distance of the route: 41748m
# Load of the route: 70
#
# Route for vehicle 12:
#  0 Load(0) ->  18 Load(12) ->  15 Load(25) ->  19 Load(34) ->  2 Load(48) ->  1 Load(72) -> 0
# Distance of the route: 38029m
# Load of the route: 72
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(13) ->  60 Load(27) ->  51 Load(33) ->  86 Load(48) ->  79 Load(59) ->  75 Load(69) -> 0
# Distance of the route: 40139m
# Load of the route: 69
#
# Route for vehicle 14:
#  0 Load(0) ->  16 Load(10) ->  12 Load(23) ->  25 Load(31) ->  22 Load(31) ->  13 Load(45) ->  10 Load(53) ->  14 Load(65) -> 0
# Distance of the route: 39762m
# Load of the route: 65
#
# Route for vehicle 15:
#  0 Load(0) ->  38 Load(18) ->  62 Load(25) ->  69 Load(36) ->  48 Load(48) -> 0
# Distance of the route: 36888m
# Load of the route: 48
#
# Total distance driven by all vehicles: 579048m
# Number of vans used: 14

# %% [markdown]
# ### Optimization for `demand_101` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_101 = [0] + demand_df['demand_101'].tolist()

def create_data_model_101():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_101]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_101(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_101():
    """Solve the CVRP problem."""
    data = create_data_model_101()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_101(data, manager, routing, solution)


if __name__ == '__main__':
    main_101()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  42 Load(6) ->  78 Load(10) ->  55 Load(18) ->  43 Load(26) ->  49 Load(31) ->  44 Load(36) ->  46 Load(41) ->  67 Load(44) ->  56 Load(49) ->  57 Load(53) ->  18 Load(62) -> 0
# Distance of the route: 46092m
# Load of the route: 62
#
# Route for vehicle 8:
#  0 Load(0) ->  41 Load(4) ->  83 Load(16) ->  59 Load(19) ->  72 Load(22) ->  71 Load(26) ->  54 Load(30) ->  110 Load(31) ->  52 Load(33) ->  94 Load(35) ->  95 Load(36) ->  107 Load(37) ->  82 Load(39) ->  108 Load(40) ->  58 Load(42) ->  81 Load(43) ->  93 Load(45) ->  89 Load(46) ->  90 Load(48) ->  70 Load(52) ->  66 Load(56) ->  76 Load(60) ->  80 Load(70) -> 0
# Distance of the route: 52058m
# Load of the route: 70
#
# Route for vehicle 9:
#  0 Load(0) ->  19 Load(6) ->  9 Load(14) ->  31 Load(20) ->  23 Load(29) ->  7 Load(39) ->  8 Load(45) ->  24 Load(46) ->  25 Load(51) ->  22 Load(52) ->  13 Load(59) ->  12 Load(66) ->  16 Load(70) -> 0
# Distance of the route: 42600m
# Load of the route: 70
#
# Route for vehicle 10:
#  0 Load(0) ->  63 Load(4) ->  45 Load(9) ->  64 Load(13) ->  53 Load(19) ->  87 Load(23) ->  88 Load(29) ->  96 Load(30) ->  100 Load(31) ->  99 Load(32) ->  106 Load(33) ->  105 Load(34) ->  104 Load(35) ->  103 Load(36) ->  109 Load(37) ->  102 Load(38) ->  98 Load(40) ->  97 Load(41) ->  101 Load(42) ->  92 Load(44) ->  91 Load(46) ->  65 Load(49) ->  73 Load(54) ->  68 Load(59) ->  38 Load(69) -> 0
# Distance of the route: 55791m
# Load of the route: 69
#
# Route for vehicle 11:
#  0 Load(0) ->  2 Load(0) ->  3 Load(10) ->  32 Load(17) ->  27 Load(23) ->  28 Load(35) ->  6 Load(44) ->  21 Load(56) ->  29 Load(63) -> 0
# Distance of the route: 41231m
# Load of the route: 63
#
# Route for vehicle 12:
#  0 Load(0) ->  1 Load(16) ->  5 Load(35) ->  30 Load(48) ->  33 Load(59) ->  4 Load(68) -> 0
# Distance of the route: 36719m
# Load of the route: 68
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(6) ->  60 Load(13) ->  75 Load(18) ->  79 Load(23) ->  86 Load(32) ->  77 Load(37) ->  61 Load(42) ->  51 Load(45) ->  34 Load(48) ->  40 Load(56) ->  36 Load(63) -> 0
# Distance of the route: 41782m
# Load of the route: 63
#
# Route for vehicle 14:
#  0 Load(0) ->  15 Load(8) ->  17 Load(15) ->  26 Load(24) ->  11 Load(33) ->  20 Load(43) ->  10 Load(48) ->  14 Load(55) -> 0
# Distance of the route: 39117m
# Load of the route: 55
#
# Route for vehicle 15:
#  0 Load(0) ->  74 Load(3) ->  39 Load(10) ->  85 Load(27) ->  35 Load(33) ->  50 Load(38) ->  84 Load(42) ->  48 Load(50) ->  69 Load(56) ->  62 Load(61) ->  47 Load(65) -> 0
# Distance of the route: 39752m
# Load of the route: 65
#
# Total distance driven by all vehicles: 395142m
# Number of vans used: 9

# %% [markdown]
# ### Optimization for `demand_111` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_111 = [0] + demand_df['demand_111'].tolist()

def create_data_model_111():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_111]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_111(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_111():
    """Solve the CVRP problem."""
    data = create_data_model_111()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_111(data, manager, routing, solution)


if __name__ == '__main__':
    main_111()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  16 Load(8) ->  12 Load(17) ->  13 Load(29) ->  22 Load(29) ->  25 Load(36) ->  24 Load(43) ->  31 Load(51) ->  11 Load(62) ->  9 Load(71) -> 0
# Distance of the route: 41073m
# Load of the route: 71
#
# Route for vehicle 4:
#  0 Load(0) ->  57 Load(5) ->  43 Load(17) ->  55 Load(28) ->  72 Load(32) ->  54 Load(41) ->  110 Load(41) ->  52 Load(45) ->  94 Load(46) ->  97 Load(46) ->  99 Load(46) ->  100 Load(46) ->  96 Load(47) ->  93 Load(48) ->  89 Load(49) ->  70 Load(55) ->  66 Load(62) ->  88 Load(64) ->  68 Load(71) -> 0
# Distance of the route: 54047m
# Load of the route: 71
#
# Route for vehicle 5:
#  0 Load(0) ->  1 Load(22) ->  30 Load(37) ->  5 Load(54) ->  19 Load(62) -> 0
# Distance of the route: 36788m
# Load of the route: 62
#
# Route for vehicle 6:
#  0 Load(0) ->  33 Load(13) ->  28 Load(27) ->  6 Load(43) ->  7 Load(61) ->  8 Load(72) -> 0
# Distance of the route: 40915m
# Load of the route: 72
#
# Route for vehicle 7:
#  0 Load(0) ->  42 Load(10) ->  78 Load(17) ->  59 Load(22) ->  83 Load(38) ->  41 Load(43) -> 0
# Distance of the route: 40075m
# Load of the route: 43
#
# Route for vehicle 8:
#  0 Load(0) ->  74 Load(4) ->  39 Load(18) ->  77 Load(26) ->  61 Load(35) ->  51 Load(41) ->  34 Load(48) ->  40 Load(60) ->  36 Load(72) -> 0
# Distance of the route: 39629m
# Load of the route: 72
#
# Route for vehicle 9:
#  0 Load(0) ->  14 Load(10) ->  10 Load(16) ->  20 Load(30) ->  23 Load(40) ->  21 Load(58) ->  4 Load(72) -> 0
# Distance of the route: 39879m
# Load of the route: 72
#
# Route for vehicle 10:
#  0 Load(0) ->  38 Load(18) ->  48 Load(32) ->  35 Load(41) ->  85 Load(71) -> 0
# Distance of the route: 37268m
# Load of the route: 71
#
# Route for vehicle 11:
#  0 Load(0) ->  49 Load(8) ->  44 Load(17) ->  46 Load(26) ->  67 Load(32) ->  56 Load(42) ->  18 Load(53) ->  80 Load(72) -> 0
# Distance of the route: 41559m
# Load of the route: 72
#
# Route for vehicle 12:
#  0 Load(0) ->  29 Load(9) ->  26 Load(21) ->  27 Load(30) ->  32 Load(42) ->  3 Load(59) ->  2 Load(69) -> 0
# Distance of the route: 38721m
# Load of the route: 69
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(16) ->  60 Load(29) ->  86 Load(46) ->  79 Load(55) ->  75 Load(65) -> 0
# Distance of the route: 39729m
# Load of the route: 65
#
# Route for vehicle 14:
#  0 Load(0) ->  63 Load(5) ->  76 Load(11) ->  53 Load(29) ->  87 Load(31) ->  84 Load(40) ->  50 Load(49) ->  17 Load(58) ->  15 Load(69) -> 0
# Distance of the route: 44025m
# Load of the route: 69
#
# Route for vehicle 15:
#  0 Load(0) ->  47 Load(6) ->  62 Load(14) ->  69 Load(25) ->  64 Load(30) ->  71 Load(36) ->  73 Load(42) ->  65 Load(48) ->  91 Load(49) ->  58 Load(53) ->  81 Load(55) ->  108 Load(55) ->  82 Load(58) ->  101 Load(58) ->  106 Load(58) ->  105 Load(58) ->  104 Load(58) ->  103 Load(58) ->  109 Load(58) ->  102 Load(58) ->  98 Load(59) ->  107 Load(59) ->  95 Load(60) ->  92 Load(61) ->  90 Load(62) ->  45 Load(72) -> 0
# Distance of the route: 55675m
# Load of the route: 72
#
# Total distance driven by all vehicles: 549383m
# Number of vans used: 13

# %% [markdown]
# ### Optimization for `demand_100` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_100 = [0] + demand_df['demand_100'].tolist()

def create_data_model_100():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_100]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_100(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_100():
    """Solve the CVRP problem."""
    data = create_data_model_100()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_100(data, manager, routing, solution)


if __name__ == '__main__':
    main_100()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  74 Load(3) ->  39 Load(9) ->  53 Load(16) ->  87 Load(20) ->  88 Load(26) ->  66 Load(31) ->  70 Load(35) ->  90 Load(38) ->  89 Load(39) ->  93 Load(42) ->  96 Load(43) ->  100 Load(44) ->  99 Load(45) ->  106 Load(46) ->  105 Load(47) ->  104 Load(48) ->  103 Load(48) ->  109 Load(49) ->  102 Load(50) ->  98 Load(52) ->  97 Load(52) ->  101 Load(53) ->  82 Load(54) ->  107 Load(55) ->  95 Load(56) ->  108 Load(57) ->  81 Load(58) ->  58 Load(61) ->  78 Load(66) ->  44 Load(72) -> 0
# Distance of the route: 59041m
# Load of the route: 72
#
# Route for vehicle 8:
#  0 Load(0) ->  49 Load(5) ->  43 Load(13) ->  73 Load(17) ->  65 Load(20) ->  91 Load(22) ->  92 Load(24) ->  94 Load(26) ->  52 Load(28) ->  110 Load(29) ->  54 Load(34) ->  71 Load(38) ->  72 Load(41) ->  55 Load(50) ->  83 Load(63) ->  59 Load(66) ->  41 Load(70) -> 0
# Distance of the route: 48632m
# Load of the route: 70
#
# Route for vehicle 9:
#  0 Load(0) ->  37 Load(6) ->  60 Load(12) ->  75 Load(16) ->  79 Load(20) ->  86 Load(29) ->  77 Load(34) ->  61 Load(39) ->  51 Load(42) ->  34 Load(45) ->  40 Load(53) ->  36 Load(60) -> 0
# Distance of the route: 41782m
# Load of the route: 60
#
# Route for vehicle 10:
#  0 Load(0) ->  1 Load(18) ->  3 Load(27) ->  32 Load(35) ->  27 Load(40) ->  26 Load(49) ->  10 Load(54) ->  12 Load(61) ->  16 Load(65) ->  18 Load(71) -> 0
# Distance of the route: 40684m
# Load of the route: 71
#
# Route for vehicle 11:
#  0 Load(0) ->  14 Load(8) ->  46 Load(13) ->  67 Load(16) ->  56 Load(21) ->  57 Load(25) ->  8 Load(30) ->  7 Load(41) ->  6 Load(49) ->  21 Load(62) ->  28 Load(72) -> 0
# Distance of the route: 45171m
# Load of the route: 72
#
# Route for vehicle 12:
#  0 Load(0) ->  2 Load(0) ->  5 Load(17) ->  30 Load(28) ->  33 Load(37) ->  4 Load(45) ->  29 Load(51) ->  17 Load(58) ->  15 Load(70) -> 0
# Distance of the route: 38028m
# Load of the route: 70
#
# Route for vehicle 13:
#  0 Load(0) ->  47 Load(4) ->  62 Load(9) ->  69 Load(16) ->  48 Load(23) ->  64 Load(27) ->  76 Load(31) ->  84 Load(35) ->  50 Load(39) ->  35 Load(45) ->  85 Load(62) -> 0
# Distance of the route: 39843m
# Load of the route: 62
#
# Route for vehicle 14:
#  0 Load(0) ->  19 Load(5) ->  9 Load(12) ->  11 Load(22) ->  31 Load(28) ->  24 Load(29) ->  23 Load(38) ->  20 Load(49) ->  13 Load(55) ->  22 Load(56) ->  25 Load(60) ->  80 Load(70) -> 0
# Distance of the route: 42792m
# Load of the route: 70
#
# Route for vehicle 15:
#  0 Load(0) ->  42 Load(6) ->  45 Load(15) ->  63 Load(20) ->  68 Load(25) ->  38 Load(37) -> 0
# Distance of the route: 38063m
# Load of the route: 37
#
# Total distance driven by all vehicles: 394036m
# Number of vans used: 9

# %% [markdown]
# ### Optimization for `demand_110` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_110 = [0] + demand_df['demand_110'].tolist()

def create_data_model_110():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_110]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_110(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_110():
    """Solve the CVRP problem."""
    data = create_data_model_110()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_110(data, manager, routing, solution)


if __name__ == '__main__':
    main_110()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  19 Load(7) ->  5 Load(18) ->  33 Load(26) ->  4 Load(40) ->  29 Load(47) ->  17 Load(55) ->  15 Load(66) -> 0
# Distance of the route: 38270m
# Load of the route: 66
#
# Route for vehicle 6:
#  0 Load(0) ->  13 Load(11) ->  20 Load(24) ->  31 Load(30) ->  24 Load(38) ->  8 Load(48) ->  7 Load(64) ->  27 Load(72) -> 0
# Distance of the route: 41900m
# Load of the route: 72
#
# Route for vehicle 7:
#  0 Load(0) ->  49 Load(6) ->  44 Load(12) ->  83 Load(28) ->  73 Load(34) ->  91 Load(35) ->  90 Load(36) ->  89 Load(36) ->  93 Load(37) ->  58 Load(40) ->  108 Load(40) ->  82 Load(43) ->  107 Load(43) ->  95 Load(44) ->  94 Load(45) ->  52 Load(48) ->  110 Load(48) ->  54 Load(56) ->  71 Load(62) ->  72 Load(65) ->  59 Load(69) ->  41 Load(72) -> 0
# Distance of the route: 52026m
# Load of the route: 72
#
# Route for vehicle 8:
#  0 Load(0) ->  36 Load(10) ->  40 Load(20) ->  74 Load(24) ->  39 Load(37) ->  85 Load(62) ->  35 Load(69) -> 0
# Distance of the route: 38661m
# Load of the route: 69
#
# Route for vehicle 9:
#  0 Load(0) ->  1 Load(21) ->  2 Load(37) ->  3 Load(46) ->  32 Load(57) ->  30 Load(70) -> 0
# Distance of the route: 37479m
# Load of the route: 70
#
# Route for vehicle 10:
#  0 Load(0) ->  47 Load(5) ->  62 Load(11) ->  69 Load(20) ->  48 Load(32) ->  50 Load(39) ->  84 Load(47) ->  76 Load(52) ->  64 Load(57) ->  45 Load(65) -> 0
# Distance of the route: 39358m
# Load of the route: 65
#
# Route for vehicle 11:
#  0 Load(0) ->  78 Load(6) ->  55 Load(15) ->  67 Load(20) ->  46 Load(26) ->  56 Load(34) ->  57 Load(39) ->  23 Load(47) ->  21 Load(61) ->  11 Load(72) -> 0
# Distance of the route: 47404m
# Load of the route: 72
#
# Route for vehicle 12:
#  0 Load(0) ->  9 Load(8) ->  26 Load(18) ->  28 Load(31) ->  6 Load(43) ->  22 Load(43) ->  25 Load(49) ->  12 Load(58) ->  10 Load(64) ->  16 Load(72) -> 0
# Distance of the route: 42978m
# Load of the route: 72
#
# Route for vehicle 13:
#  0 Load(0) ->  75 Load(8) ->  79 Load(16) ->  86 Load(31) ->  34 Load(37) ->  60 Load(49) ->  37 Load(62) -> 0
# Distance of the route: 40203m
# Load of the route: 62
#
# Route for vehicle 14:
#  0 Load(0) ->  14 Load(8) ->  18 Load(19) ->  80 Load(37) ->  63 Load(41) ->  68 Load(49) ->  38 Load(65) -> 0
# Distance of the route: 38988m
# Load of the route: 65
#
# Route for vehicle 15:
#  0 Load(0) ->  51 Load(4) ->  61 Load(11) ->  77 Load(18) ->  53 Load(31) ->  87 Load(32) ->  88 Load(33) ->  66 Load(40) ->  70 Load(46) ->  92 Load(47) ->  101 Load(47) ->  97 Load(47) ->  98 Load(47) ->  102 Load(47) ->  109 Load(47) ->  103 Load(47) ->  104 Load(47) ->  105 Load(47) ->  106 Load(47) ->  99 Load(47) ->  100 Load(47) ->  96 Load(47) ->  81 Load(49) ->  65 Load(54) ->  43 Load(64) ->  42 Load(72) -> 0
# Distance of the route: 57754m
# Load of the route: 72
#
# Total distance driven by all vehicles: 475021m
# Number of vans used: 11

# %% [markdown]
# ### Optimization for `demand_010` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_010 = [0] + demand_df['demand_010'].tolist()

def create_data_model_010():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_010]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_010(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_010():
    """Solve the CVRP problem."""
    data = create_data_model_010()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_010(data, manager, routing, solution)


if __name__ == '__main__':
    main_010()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  17 Load(8) ->  26 Load(19) ->  11 Load(30) ->  20 Load(45) ->  23 Load(54) ->  21 Load(70) -> 0
# Distance of the route: 40104m
# Load of the route: 70
#
# Route for vehicle 5:
#  0 Load(0) ->  63 Load(6) ->  53 Load(17) ->  87 Load(18) ->  88 Load(19) ->  100 Load(19) ->  99 Load(19) ->  106 Load(19) ->  105 Load(19) ->  104 Load(19) ->  103 Load(19) ->  109 Load(19) ->  102 Load(19) ->  98 Load(20) ->  97 Load(20) ->  101 Load(20) ->  96 Load(21) ->  70 Load(27) ->  66 Load(35) ->  76 Load(40) ->  45 Load(50) ->  18 Load(61) ->  14 Load(72) -> 0
# Distance of the route: 57269m
# Load of the route: 72
#
# Route for vehicle 6:
#  0 Load(0) ->  47 Load(6) ->  62 Load(13) ->  84 Load(20) ->  50 Load(27) ->  35 Load(35) ->  85 Load(64) -> 0
# Distance of the route: 38346m
# Load of the route: 64
#
# Route for vehicle 7:
#  0 Load(0) ->  13 Load(12) ->  8 Load(21) ->  7 Load(38) ->  6 Load(50) ->  28 Load(64) ->  29 Load(71) -> 0
# Distance of the route: 41407m
# Load of the route: 71
#
# Route for vehicle 8:
#  0 Load(0) ->  42 Load(7) ->  78 Load(16) ->  55 Load(28) ->  72 Load(32) ->  71 Load(39) ->  83 Load(58) ->  59 Load(63) ->  41 Load(67) -> 0
# Distance of the route: 42455m
# Load of the route: 67
#
# Route for vehicle 9:
#  0 Load(0) ->  5 Load(19) ->  2 Load(32) ->  3 Load(44) ->  1 Load(68) -> 0
# Distance of the route: 36743m
# Load of the route: 68
#
# Route for vehicle 10:
#  0 Load(0) ->  36 Load(9) ->  34 Load(17) ->  40 Load(26) ->  39 Load(37) ->  74 Load(42) ->  69 Load(52) ->  38 Load(68) -> 0
# Distance of the route: 40075m
# Load of the route: 68
#
# Route for vehicle 11:
#  0 Load(0) ->  49 Load(8) ->  44 Load(18) ->  46 Load(27) ->  67 Load(33) ->  56 Load(42) ->  57 Load(48) ->  31 Load(55) ->  24 Load(64) ->  25 Load(71) ->  22 Load(71) -> 0
# Distance of the route: 44765m
# Load of the route: 71
#
# Route for vehicle 12:
#  0 Load(0) ->  30 Load(17) ->  32 Load(27) ->  27 Load(38) ->  33 Load(48) ->  4 Load(62) ->  19 Load(70) -> 0
# Distance of the route: 38715m
# Load of the route: 70
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(11) ->  60 Load(22) ->  79 Load(30) ->  86 Load(43) ->  51 Load(48) ->  61 Load(57) ->  77 Load(64) ->  75 Load(72) -> 0
# Distance of the route: 40781m
# Load of the route: 72
#
# Route for vehicle 14:
#  0 Load(0) ->  15 Load(13) ->  16 Load(23) ->  12 Load(35) ->  10 Load(42) ->  9 Load(52) ->  80 Load(70) -> 0
# Distance of the route: 39484m
# Load of the route: 70
#
# Route for vehicle 15:
#  0 Load(0) ->  68 Load(8) ->  73 Load(15) ->  65 Load(21) ->  91 Load(22) ->  92 Load(23) ->  90 Load(24) ->  89 Load(25) ->  93 Load(26) ->  81 Load(28) ->  58 Load(31) ->  108 Load(31) ->  82 Load(34) ->  107 Load(34) ->  95 Load(35) ->  94 Load(36) ->  52 Load(39) ->  110 Load(39) ->  54 Load(46) ->  43 Load(56) ->  64 Load(62) ->  48 Load(72) -> 0
# Distance of the route: 51458m
# Load of the route: 72
#
# Total distance driven by all vehicles: 511602m
# Number of vans used: 12

# %% [markdown]
# ### Optimization for `demand_000` Archetype

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

demand_000 = [0] + demand_df['demand_000'].tolist()

def create_data_model_000():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = new_distance_matrix
    data['demands'] = [int(d) for d in demand_000]
    data['vehicle_capacities'] = [72] * 16
    data['num_vehicles'] = 16
    data['depot'] = 0
    return data

def print_solution_000(data, manager, routing, solution):
    """Prints solution on console and summarizes total distance and vans used."""
    total_distance = 0
    vans_used = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:\n'
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += f' {node_index} Load({route_load}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        plan_output += f'{node_index}\n'
        plan_output += f'Distance of the route: {route_distance}m\n'
        plan_output += f'Load of the route: {route_load}\n'
        print(plan_output)

        if route_distance > 0:
            total_distance += route_distance
            vans_used += 1
    print(f'Total distance driven by all vehicles: {total_distance}m')
    print(f'Number of vans used: {vans_used}')

def main_000():
    """Solve the CVRP problem."""
    data = create_data_model_000()

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_index):
        return data['demands'][manager.IndexToNode(from_index)]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        data['vehicle_capacities'],
        True,
        'Capacity')

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution_000(data, manager, routing, solution)


if __name__ == '__main__':
    main_000()
# Out:
# Route for vehicle 0:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) -> 0
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  78 Load(7) ->  55 Load(16) ->  43 Load(22) ->  87 Load(26) ->  53 Load(32) ->  88 Load(37) ->  66 Load(41) ->  70 Load(45) ->  92 Load(47) ->  91 Load(50) ->  65 Load(53) ->  73 Load(58) ->  71 Load(63) ->  72 Load(66) ->  59 Load(69) ->  41 Load(72) -> 0
# Distance of the route: 48755m
# Load of the route: 72
#
# Route for vehicle 8:
#  0 Load(0) ->  74 Load(4) ->  39 Load(11) ->  84 Load(15) ->  90 Load(17) ->  89 Load(18) ->  93 Load(20) ->  81 Load(21) ->  58 Load(23) ->  95 Load(24) ->  107 Load(25) ->  82 Load(27) ->  108 Load(28) ->  96 Load(29) ->  100 Load(30) ->  99 Load(31) ->  106 Load(32) ->  105 Load(33) ->  104 Load(34) ->  101 Load(35) ->  103 Load(36) ->  109 Load(37) ->  102 Load(38) ->  97 Load(39) ->  98 Load(41) ->  94 Load(43) ->  52 Load(45) ->  110 Load(46) ->  54 Load(50) ->  83 Load(65) ->  42 Load(72) -> 0
# Distance of the route: 59593m
# Load of the route: 72
#
# Route for vehicle 9:
#  0 Load(0) ->  47 Load(5) ->  62 Load(10) ->  69 Load(18) ->  48 Load(26) ->  64 Load(30) ->  76 Load(34) ->  50 Load(39) ->  35 Load(46) ->  85 Load(66) -> 0
# Distance of the route: 39326m
# Load of the route: 66
#
# Route for vehicle 10:
#  0 Load(0) ->  1 Load(16) ->  2 Load(16) ->  3 Load(26) ->  32 Load(32) ->  27 Load(41) ->  12 Load(48) ->  13 Load(57) ->  10 Load(63) ->  19 Load(69) -> 0
# Distance of the route: 40697m
# Load of the route: 69
#
# Route for vehicle 11:
#  0 Load(0) ->  33 Load(10) ->  28 Load(22) ->  6 Load(32) ->  7 Load(43) ->  8 Load(49) ->  23 Load(57) ->  21 Load(69) -> 0
# Distance of the route: 41535m
# Load of the route: 69
#
# Route for vehicle 12:
#  0 Load(0) ->  15 Load(9) ->  17 Load(16) ->  29 Load(21) ->  4 Load(30) ->  30 Load(43) ->  5 Load(65) -> 0
# Distance of the route: 37745m
# Load of the route: 65
#
# Route for vehicle 13:
#  0 Load(0) ->  37 Load(6) ->  60 Load(15) ->  75 Load(20) ->  79 Load(26) ->  86 Load(36) ->  77 Load(42) ->  61 Load(48) ->  51 Load(51) ->  34 Load(56) ->  40 Load(63) ->  36 Load(70) -> 0
# Distance of the route: 41782m
# Load of the route: 70
#
# Route for vehicle 14:
#  0 Load(0) ->  14 Load(7) ->  16 Load(11) ->  9 Load(20) ->  26 Load(29) ->  11 Load(38) ->  20 Load(50) ->  31 Load(56) ->  24 Load(57) ->  25 Load(61) ->  22 Load(62) ->  18 Load(70) -> 0
# Distance of the route: 41401m
# Load of the route: 70
#
# Route for vehicle 15:
#  0 Load(0) ->  80 Load(9) ->  57 Load(13) ->  56 Load(19) ->  67 Load(22) ->  46 Load(28) ->  44 Load(36) ->  49 Load(42) ->  68 Load(48) ->  63 Load(53) ->  45 Load(60) ->  38 Load(71) -> 0
# Distance of the route: 44433m
# Load of the route: 71
#
# Total distance driven by all vehicles: 395267m
# Number of vans used: 9

# %%
import folium

def get_routes_and_coordinates(data, manager, routing, solution, location_coords, new_waypoints):
    """Extracts routes and corresponding coordinates."""
    all_routes_coords = []

    for vehicle_id in range(data['num_vehicles']):
        route_coords = []
        index = routing.Start(vehicle_id) # This `index` is the depot's internal OR-Tools index

        # 1. Add the depot as the starting point
        depot_node_idx = manager.IndexToNode(index)
        depot_coords = location_coords[depot_node_idx]
        route_coords.append(depot_coords)

        # 2. Add the new waypoints immediately after the depot for visualization (outbound)
        route_coords.extend(new_waypoints)

        # 3. Traverse the OR-Tools solution to get all actual stops
        actual_stops_coords = []
        current_route_index = index
        current_route_index = solution.Value(routing.NextVar(current_route_index))

        while not routing.IsEnd(current_route_index):
            node_index = manager.IndexToNode(current_route_index)
            actual_stops_coords.append(location_coords[node_index])
            current_route_index = solution.Value(routing.NextVar(current_route_index))

        route_coords.extend(actual_stops_coords)

        # 4. Add the new waypoints before returning to the depot (inbound)
        # It's more realistic to traverse them in reverse order
        route_coords.extend(list(reversed(new_waypoints)))

        # 5. Add the final depot coordinate
        # The OR-Tools solution implicitly ends at the depot, so we'll just add the depot coords.
        route_coords.append(depot_coords)

        all_routes_coords.append(route_coords)

    return all_routes_coords

# Re-run main to get the solution object for demand_000
data = create_data_model_000()
manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                       data['num_vehicles'], data['depot'])
routing = pywrapcp.RoutingModel(manager)

# Create and register a transit callback (same as in main)
def distance_callback(from_index, to_index):
    return data['distance_matrix'][manager.IndexToNode(from_index)][manager.IndexToNode(to_index)]
transit_callback_index = routing.RegisterTransitCallback(distance_callback)
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# Add Capacity constraint (same as in main)
def demand_callback(from_index):
    return data['demands'][manager.IndexToNode(from_index)]
demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
routing.AddDimensionWithVehicleCapacity(
    demand_callback_index,
    0,  # null capacity slack
    data['vehicle_capacities'],  # vehicle maximum capacities
    True,  # start cumul to zero
    'Capacity')

search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

solution = routing.SolveWithParameters(search_parameters)

if solution:
    location_coords = {}
    # Get coordinates for all stations from demand_df (node_index 1 corresponds to first row of demand_df)
    for idx, row in demand_df.iterrows():
        # demand_df has 110 rows, corresponding to nodes 1-110
        # idx in demand_df corresponds to node_index = idx + 1
        location_coords[idx + 1] = (row['latitude'], row['longitude'])

    # Add the depot (index 0) with the user-provided coordinates
    depot_lat = 40.646567
    depot_lon = -74.016319
    location_coords[0] = (depot_lat, depot_lon)

    # Define the new waypoints for visualization only (moved outside the function)
    new_waypoints = [
        (40.666659, -73.995811),
        (40.690608, -74.011917),
        (40.704701, -74.016795),
        (40.726184, -74.011653),
        (40.728652, -74.031560)
    ]

    all_routes_coords = get_routes_and_coordinates(data, manager, routing, solution, location_coords, new_waypoints)

    # Create a base map centered around the mean of all coordinates
    map_center = [demand_df['latitude'].mean(), demand_df['longitude'].mean()]
    m = folium.Map(location=map_center, zoom_start=12, tiles='CartoDB Positron')

    # Add depot marker
    # Removed depot marker to prevent confusion based on previous user interaction

    # Define a list of colors for the routes
    colors = ['#FF0000', '#00FF00', '#0000FF', '#FFFF00', '#FF00FF', '#00FFFF', '#800000', '#008000', '#000080', '#808000', '#800080', '#008080', '#C0C0C0', '#808080', '#A52A2A', '#FFA500', '#DDA0DD', '#7FFF00', '#DC143C', '#00CED1']

    # Plot each route
    for i, route_coords in enumerate(all_routes_coords):
        if route_coords:
            folium.PolyLine(route_coords, color=colors[i % len(colors)], weight=2.5, opacity=1).add_to(m)
            # Add markers for each stop in the route (optional, can clutter map)
            for j, coord in enumerate(route_coords):
                # Retrieve depot_coords here for comparison
                depot_coords = location_coords[data['depot']]
                if coord not in new_waypoints and (coord != depot_coords or j == 0):
                    folium.CircleMarker(
                        location=coord,
                        radius=3,
                        color=colors[i % len(colors)],
                        fill=True,
                        fill_color=colors[i % len(colors)],
                        fill_opacity=1,
                        popup=f'Stop {j} on Vehicle {i}'
                    ).add_to(m)

    display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd69f11bbac7cc7d10f81a5ac8461339 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd69f11bbac7cc7d10f81a5ac8461339&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd69f11bbac7cc7d10f81a5ac8461339 = L.map(
#                 &quot;map_fd69f11bbac7cc7d10f81a5ac8461339&quot;,
#                 {
#                     center: [40.726090505954055, -74.0531882697198],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e5db56a597f670d5104b12ae9e5c794 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e5db56a597f670d5104b12ae9e5c794.addTo(map_fd69f11bbac7cc7d10f81a5ac8461339);
#
#
#             var poly_line_662a18052767ad8db9ad16aedd599cb7 = L.polyline(
#                 [[40.646567, -74.016319], [40.666659, -73.995811], [40.690608, -74.011917], [40.704701, -74.016795], [40.726184, -74.011653], [40.728652, -74.03156], [40.728652, -74.03156], [40.726184, -74.011653], [40.704701, -74.016795], [40.690608, -74.011917], [40.666659, -73.995811], [40.646567, -74.016319]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_fd69f11bbac7cc7d10f81a5ac8461339);
#
#
#             var circle_marker_6f6c2af51d4913498f7ac4c9ec3f8d4e = L.circleMarker(
#                 [40.646567, -74.016319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fd69f11bbac7cc7d10f81a5ac8461339);
#
#
#         var popup_15cb29d38c58178ba11588b3f189f5d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f84547d4d19d2e5c2cb200089b2c5d4c = $(`&lt;div id=&quot;html_f84547d4d19d2e5c2cb200089b2c5d4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stop 0 on Vehicle 0&lt;/div&gt;`)[0];
#                 popup_15cb29d38c58178ba11588b3f189f5d6.setContent(html_f84547d4d19d2e5c2cb200089b2c5d4c);
#
#
#
#         circle_marker_6f6c2af51d4913498f7ac4c9ec3f8d4e.bindPopup(popup_15cb29d38c58178ba11588b3f189f5d6)
#         ;
#
#
#
#
#             var poly_line_3a9a06b92007f2d6980994c1a7baced7 = L.polyline(
#                 [[40.646567, -74.016319], [40.666659, -73.995811], [40.690608, -74.011917], [40.704701, -74.016795], [40.726184, -74.011653], [40.728652, -74.03156], [40.728652, -74.03156], [40.726184, -74.011653], [40.704701, -74.016795], [40.690608, -74.011917], [40.666659, -73.995811], [40.646567, -74.016319]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_fd69f11bbac7cc7d10f81a5ac8461339);
#
#
#             var circle_marker_65a7b6fdfa55f149ae5eca3756576c3e = L.circleMarker(
#                 [40.646567, -74.016319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00FF00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &q
